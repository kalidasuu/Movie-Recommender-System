# %% [markdown]
# <a href="https://colab.research.google.com/github/kalidasuu/Movie-Recommender-System/blob/main/longformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import torch
import numpy as np
from datasets import load_dataset, Dataset, DatasetDict
from transformers import (
    LongformerTokenizer,
    LongformerForSequenceClassification,
    TrainingArguments,
    Trainer,
)
import evaluate # Hugging Face's evaluate library for metrics
import nltk
from nltk.tokenize import sent_tokenize
from tqdm.auto import tqdm # For progress bars

# --- Install/Upgrade Libraries (Run this cell first in Colab) ---
# This ensures you have the latest compatible versions of transformers, datasets, and accelerate
# which are necessary for the TrainingArguments parameters used.
# !pip install --upgrade transformers datasets accelerate
# If the above line is commented out, uncomment it and run this cell.

# Ensure NLTK 'punkt' and 'punkt_tab' tokenizers are available for sentence splitting
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    print("Downloading 'punkt' NLTK data for sentence splitting...")
    nltk.download('punkt')
    print("'punkt' downloaded.")

try:
    # 'punkt_tab' is often used by ROUGE internally, especially with stemming
    nltk.data.find('tokenizers/punkt_tab/english.pickle')
except LookupError:
    print("Downloading 'punkt_tab' NLTK data for ROUGE evaluation...")
    nltk.download('punkt_tab')
    print("'punkt_tab' downloaded.")

# Ensure ROUGE metric is available
try:
    rouge_metric = evaluate.load("rouge")
except Exception:
    print("Downloading 'rouge' metric...")
    rouge_metric = evaluate.load("rouge")
    print("'rouge' loaded.")


# --- 0. Configuration ---
MODEL_NAME = "allenai/longformer-base-4096" # Base Longformer model for extractive summarization
OUTPUT_DIR = "./longformer_extractive_govreport"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Path to your generated dataset with combined extractive summaries
# This should be the output directory from your first script
GENERATED_DATASET_DIR = "./govreport_tfidf_vscode2"

# Max length for a single sentence input to LongformerForSequenceClassification
# Longformer's max input is 4096, but here we process sentence by sentence.
# A typical sentence max length is 512, but can be adjusted.
SENTENCE_MAX_LENGTH = 512

# --- 1. Load the Generated GovReport Dataset ---
print(f"Loading generated GovReport dataset from: {GENERATED_DATASET_DIR}")
try:
    data_files = {
        "train": os.path.join(GENERATED_DATASET_DIR, "train.json"),
        "validation": os.path.join(GENERATED_DATASET_DIR, "validation.json"),
        "test": os.path.join(GENERATED_DATASET_DIR, "test.json"),
    }

    # Load the dataset. It should contain 'original_text' and 'extractive_summary_combined'
    govreport_data_splits = load_dataset("json", data_files=data_files)

    print("\nGovReport dataset loaded successfully!")
    print(govreport_data_splits)

    # --- IMPORTANT: Select a small subset for quick testing/debugging ---
    # Comment out or adjust these lines for full dataset training
    print("\nSelecting a small subset of the dataset for quick testing. Adjust or remove for full training.")
    govreport_data_splits["train"] = govreport_data_splits["train"].select(range(10))
    govreport_data_splits["validation"] = govreport_data_splits["validation"].select(range(5))
    govreport_data_splits["test"] = govreport_data_splits["test"].select(range(5))
    print("Subset selected:")
    print(govreport_data_splits)
    # --- END SUBSET SELECTION ---

    # Ensure the required columns exist
    if "original_text" not in govreport_data_splits["train"].column_names or \
       "extractive_summary" not in govreport_data_splits["train"].column_names:
        raise ValueError("Dataset must contain 'original_text' and 'extractive_summary' columns.")
except Exception as e:
    print(f"\nError loading GovReport dataset from {GENERATED_DATASET_DIR}: {e}")
    print("Please ensure the directory exists and contains 'train.json', 'validation.json', 'test.json'.")
    exit()

# --- 2. Initialize Longformer Tokenizer ---
tokenizer = LongformerTokenizer.from_pretrained(MODEL_NAME)

# --- 3. Function to Generate Extractive Labels (Oracle Summaries) ---
def generate_extractive_labels(examples):
    """
    Generates extractive labels for each sentence in a document based on ROUGE-L
    overlap with the combined extractive summary.
    """
    processed_examples = {
        "input_ids": [],
        "attention_mask": [],
        "global_attention_mask": [],
        "labels": [],
    }

    # Iterate through each example in the batch
    for i in tqdm(range(len(examples["original_text"])), desc="Generating labels"):
        document_text = examples["original_text"][i]
        extractive_summary_reference = examples["extractive_summary"][i]

        if not document_text or not extractive_summary_reference:
            continue

        sentences = sent_tokenize(document_text)
        if not sentences:
            continue

        # Calculate ROUGE-L F1 for each sentence against the extractive summary reference
        sentence_rouge_scores = []
        for sent_idx, sentence in enumerate(sentences):
            # ROUGE metric expects lists of predictions and references
            # Use postprocess_text for proper sentence splitting for ROUGE
            processed_sent, processed_ref_summary = postprocess_text_for_rouge(
                [sentence], [extractive_summary_reference]
            )
            score = rouge_metric.compute(
                predictions=processed_sent,
                references=processed_ref_summary,
                rouge_types=["rougeL"],
                use_stemmer=True,
            )
            # Store the fmeasure (F1 score). Access directly as it's a float.
            sentence_rouge_scores.append((score["rougeL"], sent_idx))

        # Sort sentences by ROUGE-L F1 score in descending order
        sentence_rouge_scores.sort(key=lambda x: x[0], reverse=True)

        # Create binary labels for each sentence in the original document order
        # Heuristic: Select sentences that have a ROUGE-L F1 score above a threshold.
        # This threshold determines what is considered a "summary" sentence.
        ROUGE_THRESHOLD = 0.20 # Adjust this threshold based on desired summary density/quality

        labels_for_document = [0] * len(sentences) # Initialize all labels to 0 (non-summary)

        # Keep track of selected sentences to avoid duplicates if needed, though not strictly
        # necessary for binary classification if only the label matters.
        # selected_sentence_indices = set()

        for score, sent_idx in sentence_rouge_scores:
            if score >= ROUGE_THRESHOLD:
                labels_for_document[sent_idx] = 1 # Mark as summary sentence
                # selected_sentence_indices.add(sent_idx)
            # Optional: You can also limit the total number of selected sentences per document
            # if len(selected_sentence_indices) >= MAX_EXTRACTIVE_SENTENCES_PER_DOC: break

        # Tokenize each sentence and add to processed_examples
        # Each sentence becomes a separate input example for the model
        for sent_idx, sentence in enumerate(sentences):
            inputs = tokenizer(
                sentence,
                truncation=True,
                max_length=SENTENCE_MAX_LENGTH,
                padding="max_length", # Pad all inputs to SENTENCE_MAX_LENGTH
                return_tensors="pt"
            )

            # Global attention mask: only on the CLS token for sentence classification
            global_attention_mask = torch.zeros_like(inputs["input_ids"])
            global_attention_mask[:, 0] = 1 # Set global attention on the first token (CLS)

            processed_examples["input_ids"].append(inputs["input_ids"].squeeze(0).tolist())
            processed_examples["attention_mask"].append(inputs["attention_mask"].squeeze(0).tolist())
            processed_examples["global_attention_mask"].append(global_attention_mask.squeeze(0).tolist())
            processed_examples["labels"].append(labels_for_document[sent_idx])

    return processed_examples

# Helper for ROUGE (ensures consistent sentence splitting for metric calculation)
def postprocess_text_for_rouge(preds, labels):
    preds = [pred.strip() for pred in preds]
    labels = [label.strip() for label in labels]
    # ROUGE typically works better when sentences are separated by newlines
    preds = ["\n".join(sent_tokenize(pred)) for pred in preds]
    labels = ["\n".join(sent_tokenize(label)) for label in labels]
    return preds, labels

# --- 4. Apply Label Generation to Dataset Splits ---
# This step will take a significant amount of time as it processes each sentence.
print("\nGenerating extractive labels for dataset splits (this may take a while)...")
# Get current column names to remove them after processing
original_column_names = govreport_data_splits["train"].column_names

tokenized_datasets = govreport_data_splits.map(
    generate_extractive_labels,
    batched=True, # Process examples in batches for efficiency
    remove_columns=original_column_names, # Remove original columns after processing
    num_proc=os.cpu_count() if os.cpu_count() else 1 # Use multiple processes if available
)
print("\nExtractive labels generated and tokenized.")
print(tokenized_datasets)

# --- 5. Define Metrics for Training ---
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)

    # Calculate precision, recall, f1, accuracy for binary classification
    # Assuming labels are 0 (non-summary) and 1 (summary)
    # We want to evaluate how well we predict the 'summary' class (1)
    from sklearn.metrics import precision_recall_fscore_support, accuracy_score

    precision, recall, f1, _ = precision_recall_fscore_support(
        labels, predictions, average='binary', pos_label=1, zero_division=0
    )
    accuracy = accuracy_score(labels, predictions)

    return {"accuracy": accuracy, "precision": precision, "recall": recall, "f1": f1}


# --- 6. Initialize LongformerForSequenceClassification Model ---
# num_labels=2 for binary classification (summary/non-summary)
model = LongformerForSequenceClassification.from_pretrained(MODEL_NAME, num_labels=2)

# If GPU is available, move model to GPU
if torch.cuda.is_available():
    model.to("cuda")
    print("LongformerForSequenceClassification model moved to GPU.")
else:
    print("No GPU found, model running on CPU.")

# --- 7. Set up Training Arguments ---
training_args = TrainingArguments(
    output_dir=OUTPUT_DIR,
    num_train_epochs=3, # Adjust number of epochs
    per_device_train_batch_size=2, # Reduced batch size for lower RAM
    per_device_eval_batch_size=2, # Reduced batch size for lower RAM
    gradient_accumulation_steps=4, # Accumulate gradients over 4 steps to simulate a batch size of 8
    gradient_checkpointing=True, # Trade computation for memory
    fp16=torch.cuda.is_available(), # Use mixed precision if GPU is available
    warmup_steps=500, # Number of warmup steps for learning rate scheduler
    weight_decay=0.01, # Strength of weight decay
    logging_dir=f"{OUTPUT_DIR}/logs",
    logging_steps=100,
    eval_strategy="epoch", # Corrected: Use eval_strategy instead of evaluation_strategy
    save_strategy="epoch", # Save model at the end of each epoch
    load_best_model_at_end=True, # Load the best model based on evaluation metric
    metric_for_best_model="f1", # Metric to use for early stopping/best model selection
    greater_is_better=True,
    report_to="none", # Disable reporting to W&B, MLflow etc.
)

# --- 8. Create Trainer ---
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)

# --- 9. Start Training ---
print("\nStarting Longformer extractive summarization training...")
trainer.train()
print("\nTraining complete! Best model saved to:", trainer.state.best_model_checkpoint)

# --- 10. Evaluate on Test Set (Optional) ---
print("\nEvaluating on test set...")
test_results = trainer.evaluate(tokenized_datasets["test"])
print("Test Results:", test_results)
# Out:
# Downloading 'punkt_tab' NLTK data for ROUGE evaluation...
# 'punkt_tab' downloaded.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Loading generated GovReport dataset from: ./govreport_tfidf_vscode2
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# GovReport dataset loaded successfully!
# DatasetDict({
#     train: Dataset({
#         features: ['original_text', 'extractive_summary', 'abstractive_summary'],
#         num_rows: 17517
#     })
#     validation: Dataset({
#         features: ['original_text', 'extractive_summary', 'abstractive_summary'],
#         num_rows: 973
#     })
#     test: Dataset({
#         features: ['original_text', 'extractive_summary', 'abstractive_summary'],
#         num_rows: 973
#     })
# })
#
# Selecting a small subset of the dataset for quick testing. Adjust or remove for full training.
# Subset selected:
# DatasetDict({
#     train: Dataset({
#         features: ['original_text', 'extractive_summary', 'abstractive_summary'],
#         num_rows: 10
#     })
#     validation: Dataset({
#         features: ['original_text', 'extractive_summary', 'abstractive_summary'],
#         num_rows: 5
#     })
#     test: Dataset({
#         features: ['original_text', 'extractive_summary', 'abstractive_summary'],
#         num_rows: 5
#     })
# })
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/694 [00:00<?, ?B/s]
# Generating extractive labels for dataset splits (this may take a while)...
# Map (num_proc=2):   0%|          | 0/10 [00:00<?, ? examples/s]
# Map (num_proc=2):   0%|          | 0/5 [00:00<?, ? examples/s]
# Map (num_proc=2):   0%|          | 0/5 [00:00<?, ? examples/s]
# Extractive labels generated and tokenized.
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask', 'global_attention_mask', 'labels'],
#         num_rows: 2074
#     })
#     validation: Dataset({
#         features: ['input_ids', 'attention_mask', 'global_attention_mask', 'labels'],
#         num_rows: 775
#     })
#     test: Dataset({
#         features: ['input_ids', 'attention_mask', 'global_attention_mask', 'labels'],
#         num_rows: 1838
#     })
# })
# pytorch_model.bin:   0%|          | 0.00/597M [00:00<?, ?B/s]
# Some weights of LongformerForSequenceClassification were not initialized from the model checkpoint at allenai/longformer-base-4096 and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# LongformerForSequenceClassification model moved to GPU.
#
# Starting Longformer extractive summarization training...
# /tmp/ipython-input-6-1737298168.py:258: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# model.safetensors:   0%|          | 0.00/597M [00:00<?, ?B/s]
#     <div>
#
#       <progress value='780' max='780' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [780/780 26:19, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.110000</td>
#       <td>0.142240</td>
#       <td>0.978065</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.072700</td>
#       <td>0.133154</td>
#       <td>0.978065</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.101800</td>
#       <td>0.124034</td>
#       <td>0.978065</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# Training complete! Best model saved to: ./longformer_extractive_govreport/checkpoint-260
#
# Evaluating on test set...
#     <div>
#
#       <progress value='919' max='919' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [919/919 02:23]
#     </div>
# Test Results: {'eval_loss': 0.018999800086021423, 'eval_accuracy': 0.9972796517954298, 'eval_precision': 0.0, 'eval_recall': 0.0, 'eval_f1': 0.0, 'eval_runtime': 143.9305, 'eval_samples_per_second': 12.77, 'eval_steps_per_second': 6.385, 'epoch': 3.0}

# %% [markdown]
# #Training with 100 samples

# %%
import os
import torch
import numpy as np
from datasets import load_dataset, Dataset, DatasetDict
from transformers import (
    LongformerTokenizer,
    LongformerForSequenceClassification,
    TrainingArguments,
    Trainer,
)
import evaluate # Hugging Face's evaluate library for metrics
import nltk
from nltk.tokenize import sent_tokenize
from tqdm.auto import tqdm # For progress bars

# --- Install/Upgrade Libraries (Run this cell first in Colab) ---
# This ensures you have the latest compatible versions of transformers, datasets, and accelerate
# which are necessary for the TrainingArguments parameters used.
# !pip install --upgrade transformers datasets accelerate
# If the above line is commented out, uncomment it and run this cell.

# Ensure NLTK 'punkt' and 'punkt_tab' tokenizers are available for sentence splitting
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    print("Downloading 'punkt' NLTK data for sentence splitting...")
    nltk.download('punkt')
    print("'punkt' downloaded.")

try:
    # 'punkt_tab' is often used by ROUGE internally, especially with stemming
    nltk.data.find('tokenizers/punkt_tab/english.pickle')
except LookupError:
    print("Downloading 'punkt_tab' NLTK data for ROUGE evaluation...")
    nltk.download('punkt_tab')
    print("'punkt_tab' downloaded.")

# Ensure ROUGE metric is available
try:
    rouge_metric = evaluate.load("rouge")
except Exception:
    print("Downloading 'rouge' metric...")
    rouge_metric = evaluate.load("rouge")
    print("'rouge' loaded.")


# --- 0. Configuration ---
MODEL_NAME = "allenai/longformer-base-4096" # Base Longformer model for extractive summarization
OUTPUT_DIR = "./longformer_extractive_govreport"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Path to your generated dataset with combined extractive summaries
# This should be the output directory from your first script
GENERATED_DATASET_DIR = "./govreport_tfidf_vscode2"

# Max length for a single sentence input to LongformerForSequenceClassification
# Longformer's max input is 4096, but here we process sentence by sentence.
# A typical sentence max length is 512, but can be adjusted.
SENTENCE_MAX_LENGTH = 512

# --- 1. Load the Generated GovReport Dataset ---
print(f"Loading generated GovReport dataset from: {GENERATED_DATASET_DIR}")
try:
    data_files = {
        "train": os.path.join(GENERATED_DATASET_DIR, "train.json"),
        "validation": os.path.join(GENERATED_DATASET_DIR, "validation.json"),
        "test": os.path.join(GENERATED_DATASET_DIR, "test.json"),
    }

    # Load the dataset. It should contain 'original_text' and 'extractive_summary_combined'
    govreport_data_splits = load_dataset("json", data_files=data_files)

    print("\nGovReport dataset loaded successfully!")
    print(govreport_data_splits)

    # --- IMPORTANT: Select a small subset for quick testing/debugging ---
    # Comment out or adjust these lines for full dataset training
    print("\nSelecting a small subset of the dataset for quick testing. Adjust or remove for full training.")
    govreport_data_splits["train"] = govreport_data_splits["train"].select(range(100))
    govreport_data_splits["validation"] = govreport_data_splits["validation"].select(range(10))
    govreport_data_splits["test"] = govreport_data_splits["test"].select(range(10))
    print("Subset selected:")
    print(govreport_data_splits)
    # --- END SUBSET SELECTION ---

    # Ensure the required columns exist
    if "original_text" not in govreport_data_splits["train"].column_names or \
       "extractive_summary" not in govreport_data_splits["train"].column_names:
        raise ValueError("Dataset must contain 'original_text' and 'extractive_summary' columns.")
except Exception as e:
    print(f"\nError loading GovReport dataset from {GENERATED_DATASET_DIR}: {e}")
    print("Please ensure the directory exists and contains 'train.json', 'validation.json', 'test.json'.")
    exit()

# --- 2. Initialize Longformer Tokenizer ---
tokenizer = LongformerTokenizer.from_pretrained(MODEL_NAME)

# --- 3. Function to Generate Extractive Labels (Oracle Summaries) ---
def generate_extractive_labels(examples):
    """
    Generates extractive labels for each sentence in a document based on ROUGE-L
    overlap with the combined extractive summary.
    """
    processed_examples = {
        "input_ids": [],
        "attention_mask": [],
        "global_attention_mask": [],
        "labels": [],
    }

    # Iterate through each example in the batch
    for i in tqdm(range(len(examples["original_text"])), desc="Generating labels"):
        document_text = examples["original_text"][i]
        extractive_summary_reference = examples["extractive_summary"][i]

        if not document_text or not extractive_summary_reference:
            continue

        sentences = sent_tokenize(document_text)
        if not sentences:
            continue

        # Calculate ROUGE-L F1 for each sentence against the extractive summary reference
        sentence_rouge_scores = []
        for sent_idx, sentence in enumerate(sentences):
            # ROUGE metric expects lists of predictions and references
            # Use postprocess_text for proper sentence splitting for ROUGE
            processed_sent, processed_ref_summary = postprocess_text_for_rouge(
                [sentence], [extractive_summary_reference]
            )
            score = rouge_metric.compute(
                predictions=processed_sent,
                references=processed_ref_summary,
                rouge_types=["rougeL"],
                use_stemmer=True,
            )
            # Store the fmeasure (F1 score). Access directly as it's a float.
            sentence_rouge_scores.append((score["rougeL"], sent_idx))

        # Sort sentences by ROUGE-L F1 score in descending order
        sentence_rouge_scores.sort(key=lambda x: x[0], reverse=True)

        # Create binary labels for each sentence in the original document order
        # Heuristic: Select sentences that have a ROUGE-L F1 score above a threshold.
        # This threshold determines what is considered a "summary" sentence.
        ROUGE_THRESHOLD = 0.20 # Adjust this threshold based on desired summary density/quality

        labels_for_document = [0] * len(sentences) # Initialize all labels to 0 (non-summary)

        # Keep track of selected sentences to avoid duplicates if needed, though not strictly
        # necessary for binary classification if only the label matters.
        # selected_sentence_indices = set()

        for score, sent_idx in sentence_rouge_scores:
            if score >= ROUGE_THRESHOLD:
                labels_for_document[sent_idx] = 1 # Mark as summary sentence
                # selected_sentence_indices.add(sent_idx)
            # Optional: You can also limit the total number of selected sentences per document
            # if len(selected_sentence_indices) >= MAX_EXTRACTIVE_SENTENCES_PER_DOC: break

        # Tokenize each sentence and add to processed_examples
        # Each sentence becomes a separate input example for the model
        for sent_idx, sentence in enumerate(sentences):
            inputs = tokenizer(
                sentence,
                truncation=True,
                max_length=SENTENCE_MAX_LENGTH,
                padding="max_length", # Pad all inputs to SENTENCE_MAX_LENGTH
                return_tensors="pt"
            )

            # Global attention mask: only on the CLS token for sentence classification
            global_attention_mask = torch.zeros_like(inputs["input_ids"])
            global_attention_mask[:, 0] = 1 # Set global attention on the first token (CLS)

            processed_examples["input_ids"].append(inputs["input_ids"].squeeze(0).tolist())
            processed_examples["attention_mask"].append(inputs["attention_mask"].squeeze(0).tolist())
            processed_examples["global_attention_mask"].append(global_attention_mask.squeeze(0).tolist())
            processed_examples["labels"].append(labels_for_document[sent_idx])

    return processed_examples

# Helper for ROUGE (ensures consistent sentence splitting for metric calculation)
def postprocess_text_for_rouge(preds, labels):
    preds = [pred.strip() for pred in preds]
    labels = [label.strip() for label in labels]
    # ROUGE typically works better when sentences are separated by newlines
    preds = ["\n".join(sent_tokenize(pred)) for pred in preds]
    labels = ["\n".join(sent_tokenize(label)) for label in labels]
    return preds, labels

# --- 4. Apply Label Generation to Dataset Splits ---
# This step will take a significant amount of time as it processes each sentence.
print("\nGenerating extractive labels for dataset splits (this may take a while)...")
# Get current column names to remove them after processing
original_column_names = govreport_data_splits["train"].column_names

tokenized_datasets = govreport_data_splits.map(
    generate_extractive_labels,
    batched=True, # Process examples in batches for efficiency
    remove_columns=original_column_names, # Remove original columns after processing
    num_proc=os.cpu_count() if os.cpu_count() else 1 # Use multiple processes if available
)
print("\nExtractive labels generated and tokenized.")
print(tokenized_datasets)

# --- 5. Define Metrics for Training ---
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)

    # Calculate precision, recall, f1, accuracy for binary classification
    # Assuming labels are 0 (non-summary) and 1 (summary)
    # We want to evaluate how well we predict the 'summary' class (1)
    from sklearn.metrics import precision_recall_fscore_support, accuracy_score

    precision, recall, f1, _ = precision_recall_fscore_support(
        labels, predictions, average='binary', pos_label=1, zero_division=0
    )
    accuracy = accuracy_score(labels, predictions)

    return {"accuracy": accuracy, "precision": precision, "recall": recall, "f1": f1}


# --- 6. Initialize LongformerForSequenceClassification Model ---
# num_labels=2 for binary classification (summary/non-summary)
model = LongformerForSequenceClassification.from_pretrained(MODEL_NAME, num_labels=2)

# If GPU is available, move model to GPU
if torch.cuda.is_available():
    model.to("cuda")
    print("LongformerForSequenceClassification model moved to GPU.")
else:
    print("No GPU found, model running on CPU.")

# --- 7. Set up Training Arguments ---
training_args = TrainingArguments(
    output_dir=OUTPUT_DIR,
    num_train_epochs=3, # Adjust number of epochs
    per_device_train_batch_size=2, # Reduced batch size for lower RAM
    per_device_eval_batch_size=2, # Reduced batch size for lower RAM
    gradient_accumulation_steps=4, # Accumulate gradients over 4 steps to simulate a batch size of 8
    gradient_checkpointing=True, # Trade computation for memory
    fp16=torch.cuda.is_available(), # Use mixed precision if GPU is available
    warmup_steps=500, # Number of warmup steps for learning rate scheduler
    weight_decay=0.01, # Strength of weight decay
    logging_dir=f"{OUTPUT_DIR}/logs",
    logging_steps=100,
    eval_strategy="epoch", # Corrected: Use eval_strategy instead of evaluation_strategy
    save_strategy="epoch", # Save model at the end of each epoch
    load_best_model_at_end=True, # Load the best model based on evaluation metric
    metric_for_best_model="f1", # Metric to use for early stopping/best model selection
    greater_is_better=True,
    report_to="none", # Disable reporting to W&B, MLflow etc.
)

# --- 8. Create Trainer ---
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)

# --- 9. Start Training ---
print("\nStarting Longformer extractive summarization training...")
trainer.train()
print("\nTraining complete! Best model saved to:", trainer.state.best_model_checkpoint)

# --- 10. Evaluate on Test Set (Optional) ---
print("\nEvaluating on test set...")
test_results = trainer.evaluate(tokenized_datasets["test"])
print("Test Results:", test_results)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1-1407217877.py in <cell line: 0>()
#       9     Trainer,
#      10 )
# ---> 11 import evaluate # Hugging Face's evaluate library for metrics
#      12 import nltk
#      13 from nltk.tokenize import sent_tokenize
#
# ModuleNotFoundError: No module named 'evaluate'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install evaluate
# !pip install rouge_score
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.5-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.34.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from evaluate) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.12.14)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2025.7.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Downloading evaluate-0.4.5-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.5
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rouge_score) (2.0.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (4.67.1)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=cae0770bd476b8aee30148b1d62409d019cf8cbc34285eb983b6be59a73d383d
#   Stored in directory: /root/.cache/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2

# %% [markdown]
# # Longformer training with checkpointing -1000 samples

# %%
import os
import torch
import numpy as np
from datasets import load_dataset, Dataset, DatasetDict, load_from_disk # Added load_from_disk
from transformers import (
    LongformerTokenizer,
    LongformerForSequenceClassification,
    TrainingArguments,
    Trainer,
)
import evaluate # Hugging Face's evaluate library for metrics
import nltk
from nltk.tokenize import sent_tokenize
from tqdm import tqdm # Direct import of tqdm
from collections import Counter # To calculate class weights
from sklearn.metrics import precision_recall_fscore_support, accuracy_score # For compute_metrics

# --- Install/Upgrade Libraries (Run this cell first in Colab) ---
# This ensures you have the latest compatible versions of transformers, datasets, and accelerate
# which are necessary for the TrainingArguments parameters used.
# !pip install --upgrade transformers datasets accelerate
# If the above line is commented out, uncomment it and run this cell.

# Ensure NLTK 'punkt' and 'punkt_tab' tokenizers are available for sentence splitting
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    print("Downloading 'punkt' NLTK data for sentence splitting...")
    nltk.download('punkt')
    print("'punkt' downloaded.")

try:
    # 'punkt_tab' is often used by ROUGE internally, especially with stemming
    nltk.data.find('tokenizers/punkt_tab/english.pickle')
except LookupError:
    print("Downloading 'punkt_tab' NLTK data for ROUGE evaluation...")
    nltk.download('punkt_tab')
    print("'punkt_tab' downloaded.")

# Ensure ROUGE metric is available
try:
    rouge_metric = evaluate.load("rouge")
except Exception:
    print("Downloading 'rouge' metric...")
    rouge_metric = evaluate.load("rouge")
    print("'rouge' loaded.")


# --- 0. Configuration ---
MODEL_NAME = "allenai/longformer-base-4096" # Base Longformer model for extractive summarization
OUTPUT_DIR = "./longformer_extractive_govreport"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Path to your raw dataset with combined extractive summaries (input for label generation)
GENERATED_DATASET_DIR = "./govreport_tfidf_vscode2"

# New: Path to store the processed (labeled and tokenized) dataset
PROCESSED_DATA_DIR = "/content/drive/My Drive/longformer_processed_govreport" # Ensure this is a Drive path for persistence
os.makedirs(PROCESSED_DATA_DIR, exist_ok=True)

# Max length for a single sentence input to LongformerForSequenceClassification
SENTENCE_MAX_LENGTH = 512

# --- 1. Load or Generate Processed Dataset ---
tokenized_datasets = None
govreport_data_splits = None # Initialize to None

# Check if processed dataset already exists on disk
if os.path.exists(PROCESSED_DATA_DIR) and \
   os.path.exists(os.path.join(PROCESSED_DATA_DIR, "train")) and \
   os.path.exists(os.path.join(PROCESSED_DATA_DIR, "validation")) and \
   os.path.exists(os.path.join(PROCESSED_DATA_DIR, "test")):
    print(f"Loading processed dataset from: {PROCESSED_DATA_DIR}")
    try:
        tokenized_datasets = DatasetDict.load_from_disk(PROCESSED_DATA_DIR)
        print("\nProcessed dataset loaded successfully!")
        print(tokenized_datasets)
    except Exception as e:
        print(f"\nError loading processed dataset from {PROCESSED_DATA_DIR}: {e}")
        print("Attempting to regenerate dataset as loading failed...")
        tokenized_datasets = None # Reset to trigger regeneration
else: # This block runs if processed data is NOT found, meaning we need to load raw and process
    # --- Load the Generated GovReport Dataset (RAW) ---
    print(f"Loading raw GovReport dataset from: {GENERATED_DATASET_DIR}")
    try:
        data_files = {
            "train": os.path.join(GENERATED_DATASET_DIR, "train.json"),
            "validation": os.path.join(GENERATED_DATASET_DIR, "validation.json"),
            "test": os.path.join(GENERATED_DATASET_DIR, "test.json"),
        }
        govreport_data_splits = load_dataset("json", data_files=data_files)
        print("\nRaw GovReport dataset loaded successfully!")
        print(govreport_data_splits)

        # --- IMPORTANT: Select a small subset for quick testing/debugging ---
        print("\nSelecting a small subset of the dataset for quick testing. Adjust or remove for full training.")
        govreport_data_splits["train"] = govreport_data_splits["train"].select(range(1000))
        govreport_data_splits["validation"] = govreport_data_splits["validation"].select(range(100))
        govreport_data_splits["test"] = govreport_data_splits["test"].select(range(100))
        print("Subset selected:")
        print(govreport_data_splits)
        # --- END SUBSET SELECTION ---

        # Ensure the required columns exist
        if "original_text" not in govreport_data_splits["train"].column_names or \
           "extractive_summary" not in govreport_data_splits["train"].column_names:
            raise ValueError("Dataset must contain 'original_text' and 'extractive_summary' columns.")
    except Exception as e:
        print(f"\nError loading raw GovReport dataset from {GENERATED_DATASET_DIR}: {e}")
        print("Please ensure the directory exists and contains 'train.json', 'validation.json', 'test.json'.")
        exit() # Exit if raw data loading fails

    # --- Initialize Longformer Tokenizer (needed for generate_extractive_labels) ---
    # This tokenizer is specifically for the data preprocessing step
    tokenizer_for_preprocessing = LongformerTokenizer.from_pretrained(MODEL_NAME)

    # --- 3. Function to Generate Extractive Labels (Oracle Summaries) ---
    def generate_extractive_labels(examples):
        """
        Generates extractive labels for each sentence in a document based on ROUGE-L
        overlap with the combined extractive summary.
        """
        processed_examples = {
            "input_ids": [],
            "attention_mask": [],
            "global_attention_mask": [],
            "labels": [],
        }

        for i in tqdm(range(len(examples["original_text"])), desc="Generating labels"):
            document_text = examples["original_text"][i]
            extractive_summary_reference = examples["extractive_summary"][i]

            if not document_text or not extractive_summary_reference:
                continue

            sentences = sent_tokenize(document_text)
            if not sentences:
                continue

            sentence_rouge_scores = []
            for sent_idx, sentence in enumerate(sentences):
                processed_sent, processed_ref_summary = postprocess_text_for_rouge(
                    [sentence], [extractive_summary_reference]
                )
                score = rouge_metric.compute(
                    predictions=processed_sent,
                    references=processed_ref_summary,
                    rouge_types=["rougeL"],
                    use_stemmer=True,
                )
                sentence_rouge_scores.append((score["rougeL"], sent_idx))

            sentence_rouge_scores.sort(key=lambda x: x[0], reverse=True)

            ROUGE_THRESHOLD = 0.20 # Adjust this threshold based on desired summary density/quality
            labels_for_document = [0] * len(sentences)

            for score, sent_idx in sentence_rouge_scores:
                if score >= ROUGE_THRESHOLD:
                    labels_for_document[sent_idx] = 1

            for sent_idx, sentence in enumerate(sentences):
                inputs = tokenizer_for_preprocessing( # Use the tokenizer defined for preprocessing
                    sentence,
                    truncation=True,
                    max_length=SENTENCE_MAX_LENGTH,
                    padding="max_length",
                    return_tensors="pt"
                )

                global_attention_mask = torch.zeros_like(inputs["input_ids"])
                global_attention_mask[:, 0] = 1

                processed_examples["input_ids"].append(inputs["input_ids"].squeeze(0).tolist())
                processed_examples["attention_mask"].append(inputs["attention_mask"].squeeze(0).tolist())
                processed_examples["global_attention_mask"].append(global_attention_mask.squeeze(0).tolist())
                processed_examples["labels"].append(labels_for_document[sent_idx])

        return processed_examples

    # Helper for ROUGE (ensures consistent sentence splitting for metric calculation)
    def postprocess_text_for_rouge(preds, labels):
        preds = [pred.strip() for pred in preds]
        labels = [label.strip() for label in labels]
        preds = ["\n".join(sent_tokenize(pred)) for pred in preds]
        labels = ["\n".join(sent_tokenize(label)) for label in labels]
        return preds, labels

    # --- 4. Apply Label Generation to Dataset Splits ---
    print("\nGenerating extractive labels for dataset splits (this may take a while)...")
    # This line is now safely inside the else block where govreport_data_splits is guaranteed to be defined
    original_column_names = govreport_data_splits["train"].column_names

    tokenized_datasets = govreport_data_splits.map(
        generate_extractive_labels,
        batched=True,
        remove_columns=original_column_names,
        num_proc=os.cpu_count() if os.cpu_count() else 1
    )
    print("\nExtractive labels generated and tokenized.")
    print(tokenized_datasets)

    # --- Save the Processed Dataset ---
    print(f"\nSaving processed dataset to: {PROCESSED_DATA_DIR}")
    tokenized_datasets.save_to_disk(PROCESSED_DATA_DIR)
    print("Processed dataset saved successfully!")

# Ensure tokenizer is initialized globally for the Trainer, regardless of data loading path
tokenizer = LongformerTokenizer.from_pretrained(MODEL_NAME)

# --- 5. Define Metrics for Training ---
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)

    precision, recall, f1, _ = precision_recall_fscore_support(
        labels, predictions, average='binary', pos_label=1, zero_division=0
    )
    accuracy = accuracy_score(labels, predictions)

    return {"accuracy": accuracy, "precision": precision, "recall": recall, "f1": f1}


# --- 6. Initialize LongformerForSequenceClassification Model ---
model = LongformerForSequenceClassification.from_pretrained(MODEL_NAME, num_labels=2)

# --- Calculate Class Weights for Imbalanced Data ---
train_labels = tokenized_datasets["train"]["labels"]
label_counts = Counter(train_labels)
num_class_0 = label_counts.get(0, 0)
num_class_1 = label_counts.get(1, 0)
total_samples = len(train_labels)

print(f"\nLabel distribution in training set: Class 0 (Non-summary): {num_class_0}, Class 1 (Summary): {num_class_1}")

if num_class_0 > 0 and num_class_1 > 0:
    weight_for_class_0 = total_samples / (2 * num_class_0)
    weight_for_class_1 = total_samples / (2 * num_class_1)
    class_weights = torch.tensor([weight_for_class_0, weight_for_class_1], dtype=torch.float)
    print(f"Calculated class weights: Class 0: {weight_for_class_0:.4f}, Class 1: {weight_for_class_1:.4f}")
else:
    print("Warning: One or both classes are missing in the training data. Using uniform weights.")
    class_weights = torch.tensor([1.0, 1.0], dtype=torch.float)


# Move class weights to the same device as the model
if torch.cuda.is_available():
    class_weights = class_weights.to("cuda")
    model.to("cuda")
    print("LongformerForSequenceClassification model and class weights moved to GPU.")
else:
    print("No GPU found, model and class weights running on CPU.")

# Override the default loss function to use class weights
class CustomTrainer(Trainer):
    # Updated signature to accept num_items_in_batch and other kwargs
    def compute_loss(self, model, inputs, return_outputs=False, num_items_in_batch=None, **kwargs):
        labels = inputs.pop("labels")
        outputs = model(**inputs)
        logits = outputs.logits
        loss_fct = torch.nn.CrossEntropyLoss(weight=class_weights)
        loss = loss_fct(logits.view(-1, self.model.config.num_labels), labels.view(-1))
        return (loss, outputs) if return_outputs else loss

# --- 7. Set up Training Arguments ---
training_args = TrainingArguments(
    output_dir=OUTPUT_DIR,
    num_train_epochs=3,
    per_device_train_batch_size=2,
    per_device_eval_batch_size=2,
    gradient_accumulation_steps=4,
    gradient_checkpointing=True,
    fp16=torch.cuda.is_available(), # Enable mixed precision training if GPU is available
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir=f"{OUTPUT_DIR}/logs",
    logging_steps=100,
    eval_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    metric_for_best_model="f1",
    greater_is_better=True,
    report_to="none",
)

# --- 8. Create Trainer ---
trainer = CustomTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)

# --- 9. Start Training ---
print("\nStarting Longformer extractive summarization training...")

# Check for existing checkpoints to resume from
last_checkpoint = None
if os.path.isdir(training_args.output_dir):
    checkpoints = [d for d in os.listdir(training_args.output_dir) if d.startswith("checkpoint-")]
    if checkpoints:
        last_checkpoint = os.path.join(training_args.output_dir, max(checkpoints, key=lambda x: int(x.split('-')[1])))
        print(f"Found existing checkpoint: {last_checkpoint}. Resuming training from here.")

trainer.train(resume_from_checkpoint=last_checkpoint)

print("\nTraining complete! Best model saved to:", trainer.state.best_model_checkpoint)

# --- 10. Evaluate on Test Set (Optional) ---
print("\nEvaluating on test set...")
test_results = trainer.evaluate(tokenized_datasets["test"])
print("Test Results:", test_results)
# Out:
# Downloading 'punkt_tab' NLTK data for ROUGE evaluation...
# 'punkt_tab' downloaded.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Loading processed dataset from: /content/drive/My Drive/longformer_processed_govreport
#
# Processed dataset loaded successfully!
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask', 'global_attention_mask', 'labels'],
#         num_rows: 259432
#     })
#     validation: Dataset({
#         features: ['input_ids', 'attention_mask', 'global_attention_mask', 'labels'],
#         num_rows: 27214
#     })
#     test: Dataset({
#         features: ['input_ids', 'attention_mask', 'global_attention_mask', 'labels'],
#         num_rows: 28855
#     })
# })
# Some weights of LongformerForSequenceClassification were not initialized from the model checkpoint at allenai/longformer-base-4096 and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Label distribution in training set: Class 0 (Non-summary): 253686, Class 1 (Summary): 5746
# Calculated class weights: Class 0: 0.5113, Class 1: 22.5750
# LongformerForSequenceClassification model and class weights moved to GPU.
#
# Starting Longformer extractive summarization training...
# /tmp/ipython-input-1781087401.py:288: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `CustomTrainer.__init__`. Use `processing_class` instead.
#   trainer = CustomTrainer(
# Found existing checkpoint: ./longformer_extractive_govreport/checkpoint-6268. Resuming training from here.
#     <div>
#
#       <progress value='6275' max='97287' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 6275/97287 00:09 < 47:39:09, 0.53 it/s, Epoch 0.19/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1781087401.py in <cell line: 0>()
#     306         print(f"Found existing checkpoint: {last_checkpoint}. Resuming training from here.")
#     307
# --> 308 trainer.train(resume_from_checkpoint=last_checkpoint)
#     309
#     310 print("\nTraining complete! Best model saved to:", trainer.state.best_model_checkpoint)
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2235                 hf_hub_utils.enable_progress_bars()
#    2236         else:
# -> 2237             return inner_training_loop(
#    2238                 args=args,
#    2239                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2576                     )
#    2577                     with context():
# -> 2578                         tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2579
#    2580                     if (
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in training_step(***failed resolving arguments***)
#    3838                 kwargs["scale_wrt_gas"] = False
#    3839
# -> 3840             self.accelerator.backward(loss, **kwargs)
#    3841
#    3842             return loss.detach()
#
# /usr/local/lib/python3.11/dist-packages/accelerate/accelerator.py in backward(self, loss, **kwargs)
#    2572             return
#    2573         elif self.scaler is not None:
# -> 2574             self.scaler.scale(loss).backward(**kwargs)
#    2575         elif learning_rate is not None and self.has_lomo_optimizer:
#    2576             self.lomo_backward(loss, learning_rate)
#
# /usr/local/lib/python3.11/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     624                 inputs=inputs,
#     625             )
# --> 626         torch.autograd.backward(
#     627             self, gradient, retain_graph, create_graph, inputs=inputs
#     628         )
#
# /usr/local/lib/python3.11/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     345     # some Python versions print out the first line of a multi-line function
#     346     # calls in the traceback and some print out the last line
# --> 347     _engine_run_backward(
#     348         tensors,
#     349         grad_tensors_,
#
# /usr/local/lib/python3.11/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     821         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822     try:
# --> 823         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824             t_outputs, *args, **kwargs
#     825         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %% [markdown]
# #Data tokenization for 1000-100-100 samples with checkpointing

# %%
import os
import torch
import numpy as np
from datasets import load_dataset, Dataset, DatasetDict
from transformers import LongformerTokenizer
import evaluate # Hugging Face's evaluate library for metrics
import nltk
from nltk.tokenize import sent_tokenize
from tqdm import tqdm # Direct import of tqdm
# For progress bars

# --- Install/Upgrade Libraries (Run this cell first in Colab) ---
# This ensures you have the latest compatible versions of transformers, datasets, and accelerate
# which are necessary for the TrainingArguments parameters used.
# !pip install --upgrade transformers datasets accelerate
# If the above line is commented out, uncomment it and run this cell.

# Ensure NLTK 'punkt' and 'punkt_tab' tokenizers are available for sentence splitting
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    print("Downloading 'punkt' NLTK data for sentence splitting...")
    nltk.download('punkt')
    print("'punkt' downloaded.")

try:
    # 'punkt_tab' is often used by ROUGE internally, especially with stemming
    nltk.data.find('tokenizers/punkt_tab/english.pickle')
except LookupError:
    print("Downloading 'punkt_tab' NLTK data for ROUGE evaluation...")
    nltk.download('punkt_tab')
    print("'punkt_tab' downloaded.")

# Ensure ROUGE metric is available
try:
    rouge_metric = evaluate.load("rouge")
except Exception:
    print("Downloading 'rouge' metric...")
    rouge_metric = evaluate.load("rouge")
    print("'rouge' loaded.")


# --- 0. Configuration ---
MODEL_NAME = "allenai/longformer-base-4096" # Base Longformer model for tokenizer
# Path to your raw dataset with combined extractive summaries
# IMPORTANT: If your raw data is also in Google Drive, update this path accordingly
GENERATED_DATASET_DIR = "./govreport_tfidf_vscode2"

# Path to store the processed (labeled and tokenized) dataset
# IMPORTANT: Use a Google Drive path for persistence in Colab
PROCESSED_DATA_DIR = "/content/drive/My Drive/longformer_processed_govreport"
os.makedirs(PROCESSED_DATA_DIR, exist_ok=True)

# Max length for a single sentence input to LongformerForSequenceClassification
SENTENCE_MAX_LENGTH = 512

# --- 1. Load the Raw GovReport Dataset ---
print(f"Loading raw GovReport dataset from: {GENERATED_DATASET_DIR}")
try:
    data_files = {
        "train": os.path.join(GENERATED_DATASET_DIR, "train.json"),
        "validation": os.path.join(GENERATED_DATASET_DIR, "validation.json"),
        "test": os.path.join(GENERATED_DATASET_DIR, "test.json"),
    }

    govreport_data_splits = load_dataset("json", data_files=data_files)

    print("\nRaw GovReport dataset loaded successfully!")
    print(govreport_data_splits)

    # --- IMPORTANT: Select a small subset for quick testing/debugging ---
    # For full dataset processing, comment out or adjust these lines.
    print("\nSelecting a small subset of the dataset for quick testing. Adjust or remove for full processing.")
    govreport_data_splits["train"] = govreport_data_splits["train"].select(range(1000))
    govreport_data_splits["validation"] = govreport_data_splits["validation"].select(range(100))
    govreport_data_splits["test"] = govreport_data_splits["test"].select(range(100))
    print("Subset selected:")
    print(govreport_data_splits)
    # --- END SUBSET SELECTION ---

    # Ensure the required columns exist
    if "original_text" not in govreport_data_splits["train"].column_names or \
       "extractive_summary" not in govreport_data_splits["train"].column_names:
        raise ValueError("Dataset must contain 'original_text' and 'extractive_summary' columns.")
except Exception as e:
    print(f"\nError loading raw GovReport dataset from {GENERATED_DATASET_DIR}: {e}")
    print("Please ensure the directory exists and contains 'train.json', 'validation.json', 'test.json'.")
    exit()

# --- 2. Initialize Longformer Tokenizer ---
tokenizer = LongformerTokenizer.from_pretrained(MODEL_NAME)

# --- 3. Function to Generate Extractive Labels (Oracle Summaries) ---
# This function also performs the tokenization of sentences
def generate_extractive_labels(examples):
    """
    Generates extractive labels for each sentence in a document based on ROUGE-L
    overlap with the combined extractive summary, and tokenizes the sentences.
    """
    processed_examples = {
        "input_ids": [],
        "attention_mask": [],
        "global_attention_mask": [],
        "labels": [],
    }

    # Use tqdm explicitly
    for i in tqdm(range(len(examples["original_text"])), desc="Generating labels and tokenizing"):
        document_text = examples["original_text"][i]
        extractive_summary_reference = examples["extractive_summary"][i]

        if not document_text or not extractive_summary_reference:
            continue

        sentences = sent_tokenize(document_text)
        if not sentences:
            continue

        sentence_rouge_scores = []
        for sent_idx, sentence in enumerate(sentences):
            processed_sent, processed_ref_summary = postprocess_text_for_rouge(
                [sentence], [extractive_summary_reference]
            )
            score = rouge_metric.compute(
                predictions=processed_sent,
                references=processed_ref_summary,
                rouge_types=["rougeL"],
                use_stemmer=True,
            )
            sentence_rouge_scores.append((score["rougeL"], sent_idx))

        sentence_rouge_scores.sort(key=lambda x: x[0], reverse=True)

        ROUGE_THRESHOLD = 0.20 # Adjust this threshold based on desired summary density/quality
        labels_for_document = [0] * len(sentences)

        for score, sent_idx in sentence_rouge_scores:
            if score >= ROUGE_THRESHOLD:
                labels_for_document[sent_idx] = 1

        for sent_idx, sentence in enumerate(sentences):
            inputs = tokenizer( # This is where tokenization happens
                sentence,
                truncation=True,
                max_length=SENTENCE_MAX_LENGTH,
                padding="max_length", # Pad all inputs to SENTENCE_MAX_LENGTH
                return_tensors="pt"
            )

            global_attention_mask = torch.zeros_like(inputs["input_ids"])
            global_attention_mask[:, 0] = 1 # Set global attention on the first token (CLS)

            processed_examples["input_ids"].append(inputs["input_ids"].squeeze(0).tolist())
            processed_examples["attention_mask"].append(inputs["attention_mask"].squeeze(0).tolist())
            processed_examples["global_attention_mask"].append(global_attention_mask.squeeze(0).tolist())
            processed_examples["labels"].append(labels_for_document[sent_idx])

    return processed_examples

# Helper for ROUGE (ensures consistent sentence splitting for metric calculation)
def postprocess_text_for_rouge(preds, labels):
    preds = [pred.strip() for pred in preds]
    labels = [label.strip() for label in labels]
    preds = ["\n".join(sent_tokenize(pred)) for pred in preds]
    labels = ["\n".join(sent_tokenize(label)) for label in labels]
    return preds, labels

# --- 4. Apply Label Generation and Tokenization to Dataset Splits ---
print("\nApplying label generation and tokenization to dataset splits (this may take a while)...")
original_column_names = govreport_data_splits["train"].column_names

tokenized_datasets = govreport_data_splits.map(
    generate_extractive_labels,
    batched=True, # Process examples in batches for efficiency
    remove_columns=original_column_names, # Remove original columns after processing
    num_proc=1 # IMPORTANT: Set num_proc=1 for more reliable saving to Google Drive
)
print("\nLabels generated and sentences tokenized.")
print(tokenized_datasets)

# --- 5. Save the Processed Dataset ---
print(f"\nSaving processed dataset to: {PROCESSED_DATA_DIR}")
try:
    tokenized_datasets.save_to_disk(PROCESSED_DATA_DIR)
    print("Processed dataset saved successfully!")

    # --- Post-save verification ---
    expected_splits = ["train", "validation", "test"]
    all_splits_saved = True
    for split in expected_splits:
        split_path = os.path.join(PROCESSED_DATA_DIR, split)
        if not os.path.exists(split_path) or not os.listdir(split_path):
            print(f"Warning: Directory for split '{split}' not found or empty at {split_path}")
            all_splits_saved = False
    if all_splits_saved:
        print("All expected dataset splits verified on disk.")
    else:
        print("Warning: Some dataset splits might be missing or incomplete. Please check the directory.")

except Exception as e:
    print(f"Error saving processed dataset to {PROSED_DATA_DIR}: {e}")
    print("The save operation might have been interrupted or failed. Please check your Google Drive connection and disk space.")


print("\nThis script has completed the data preparation (tokenization and label generation).")
print(f"The processed dataset is saved to: {PROCESSED_DATA_DIR}")
print("You can now use this dataset for training your Longformer model without regenerating labels.")
# Out:
# Downloading 'punkt_tab' NLTK data for ROUGE evaluation...
# 'punkt_tab' downloaded.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Loading raw GovReport dataset from: ./govreport_tfidf_vscode2
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Raw GovReport dataset loaded successfully!
# DatasetDict({
#     train: Dataset({
#         features: ['original_text', 'extractive_summary', 'abstractive_summary'],
#         num_rows: 17517
#     })
#     validation: Dataset({
#         features: ['original_text', 'extractive_summary', 'abstractive_summary'],
#         num_rows: 973
#     })
#     test: Dataset({
#         features: ['original_text', 'extractive_summary', 'abstractive_summary'],
#         num_rows: 973
#     })
# })
#
# Selecting a small subset of the dataset for quick testing. Adjust or remove for full processing.
# Subset selected:
# DatasetDict({
#     train: Dataset({
#         features: ['original_text', 'extractive_summary', 'abstractive_summary'],
#         num_rows: 1000
#     })
#     validation: Dataset({
#         features: ['original_text', 'extractive_summary', 'abstractive_summary'],
#         num_rows: 100
#     })
#     test: Dataset({
#         features: ['original_text', 'extractive_summary', 'abstractive_summary'],
#         num_rows: 100
#     })
# })
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/694 [00:00<?, ?B/s]
# Applying label generation and tokenization to dataset splits (this may take a while)...
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Generating labels and tokenizing:   0%|          | 0/1000 [00:00<?, ?it/s]
# Generating labels and tokenizing:   0%|          | 1/1000 [00:24<6:49:16, 24.58s/it]
# Generating labels and tokenizing:   0%|          | 2/1000 [00:48<6:41:05, 24.11s/it]
# Generating labels and tokenizing:   0%|          | 3/1000 [01:03<5:33:04, 20.04s/it]
# Generating labels and tokenizing:   0%|          | 4/1000 [01:17<4:51:46, 17.58s/it]
# Generating labels and tokenizing:   1%|          | 6/1000 [01:29<3:10:47, 11.52s/it]
# Generating labels and tokenizing:   1%|          | 7/1000 [01:38<2:58:36, 10.79s/it]
# Generating labels and tokenizing:   1%|          | 8/1000 [01:57<3:38:19, 13.20s/it]
# Generating labels and tokenizing:   1%|          | 9/1000 [02:08<3:26:25, 12.50s/it]
# Generating labels and tokenizing:   1%|          | 10/1000 [02:32<4:20:21, 15.78s/it]
# Generating labels and tokenizing:   1%|          | 11/1000 [02:54<4:52:44, 17.76s/it]
# Generating labels and tokenizing:   1%|          | 12/1000 [03:03<4:07:00, 15.00s/it]
# Generating labels and tokenizing:   1%|▏         | 13/1000 [03:10<3:29:59, 12.77s/it]
# Generating labels and tokenizing:   1%|▏         | 14/1000 [03:40<4:54:54, 17.95s/it]
# Generating labels and tokenizing:   2%|▏         | 15/1000 [03:50<4:14:11, 15.48s/it]
# Generating labels and tokenizing:   2%|▏         | 17/1000 [04:10<3:30:33, 12.85s/it]
# Generating labels and tokenizing:   2%|▏         | 18/1000 [04:49<5:17:00, 19.37s/it]
# Generating labels and tokenizing:   2%|▏         | 19/1000 [05:06<5:05:55, 18.71s/it]
# Generating labels and tokenizing:   2%|▏         | 20/1000 [05:27<5:17:36, 19.45s/it]
# Generating labels and tokenizing:   2%|▏         | 21/1000 [05:41<4:51:27, 17.86s/it]
# Generating labels and tokenizing:   2%|▏         | 22/1000 [06:08<5:32:21, 20.39s/it]
# Generating labels and tokenizing:   2%|▏         | 23/1000 [06:28<5:32:00, 20.39s/it]
# Generating labels and tokenizing:   2%|▏         | 24/1000 [06:43<5:03:50, 18.68s/it]
# Generating labels and tokenizing:   2%|▎         | 25/1000 [07:06<5:27:25, 20.15s/it]
# Generating labels and tokenizing:   3%|▎         | 26/1000 [07:22<5:03:24, 18.69s/it]
# Generating labels and tokenizing:   3%|▎         | 27/1000 [08:02<6:47:06, 25.10s/it]
# Generating labels and tokenizing:   3%|▎         | 28/1000 [08:37<7:37:19, 28.23s/it]
# Generating labels and tokenizing:   3%|▎         | 30/1000 [08:51<4:55:27, 18.28s/it]
# Generating labels and tokenizing:   3%|▎         | 31/1000 [09:00<4:21:07, 16.17s/it]
# Generating labels and tokenizing:   3%|▎         | 32/1000 [09:18<4:27:10, 16.56s/it]
# Generating labels and tokenizing:   3%|▎         | 33/1000 [09:33<4:18:33, 16.04s/it]
# Generating labels and tokenizing:   3%|▎         | 34/1000 [09:42<3:49:14, 14.24s/it]
# Generating labels and tokenizing:   4%|▎         | 35/1000 [10:28<6:13:50, 23.24s/it]
# Generating labels and tokenizing:   4%|▎         | 36/1000 [10:41<5:25:18, 20.25s/it]
# Generating labels and tokenizing:   4%|▍         | 38/1000 [11:02<4:15:15, 15.92s/it]
# Generating labels and tokenizing:   4%|▍         | 39/1000 [11:15<4:00:51, 15.04s/it]
# Generating labels and tokenizing:   4%|▍         | 40/1000 [11:27<3:47:43, 14.23s/it]
# Generating labels and tokenizing:   4%|▍         | 41/1000 [11:33<3:15:25, 12.23s/it]
# Generating labels and tokenizing:   4%|▍         | 44/1000 [11:40<1:48:47,  6.83s/it]
# Generating labels and tokenizing:   4%|▍         | 45/1000 [11:47<1:51:21,  7.00s/it]
# Generating labels and tokenizing:   5%|▍         | 46/1000 [12:18<3:16:10, 12.34s/it]
# Generating labels and tokenizing:   5%|▍         | 47/1000 [12:43<4:05:09, 15.44s/it]
# Generating labels and tokenizing:   5%|▍         | 48/1000 [13:10<4:50:55, 18.34s/it]
# Generating labels and tokenizing:   5%|▍         | 49/1000 [13:19<4:13:15, 15.98s/it]
# Generating labels and tokenizing:   5%|▌         | 50/1000 [13:31<3:54:00, 14.78s/it]
# Generating labels and tokenizing:   5%|▌         | 51/1000 [13:44<3:46:11, 14.30s/it]
# Generating labels and tokenizing:   5%|▌         | 52/1000 [14:07<4:22:26, 16.61s/it]
# Generating labels and tokenizing:   5%|▌         | 53/1000 [14:13<3:37:25, 13.78s/it]
# Generating labels and tokenizing:   5%|▌         | 54/1000 [14:18<2:53:27, 11.00s/it]
# Generating labels and tokenizing:   6%|▌         | 55/1000 [14:24<2:29:44,  9.51s/it]
# Generating labels and tokenizing:   6%|▌         | 56/1000 [14:42<3:10:52, 12.13s/it]
# Generating labels and tokenizing:   6%|▌         | 57/1000 [14:49<2:47:16, 10.64s/it]
# Generating labels and tokenizing:   6%|▌         | 58/1000 [15:33<5:20:06, 20.39s/it]
# Generating labels and tokenizing:   6%|▌         | 59/1000 [15:47<4:53:06, 18.69s/it]
# Generating labels and tokenizing:   6%|▌         | 60/1000 [15:57<4:10:08, 15.97s/it]
# Generating labels and tokenizing:   6%|▌         | 61/1000 [16:26<5:12:55, 20.00s/it]
# Generating labels and tokenizing:   6%|▌         | 62/1000 [16:39<4:40:05, 17.92s/it]
# Generating labels and tokenizing:   6%|▋         | 63/1000 [17:01<4:59:37, 19.19s/it]
# Generating labels and tokenizing:   6%|▋         | 64/1000 [17:15<4:34:39, 17.61s/it]
# Generating labels and tokenizing:   7%|▋         | 66/1000 [17:33<3:32:45, 13.67s/it]
# Generating labels and tokenizing:   7%|▋         | 67/1000 [17:46<3:26:13, 13.26s/it]
# Generating labels and tokenizing:   7%|▋         | 68/1000 [17:57<3:17:54, 12.74s/it]
# Generating labels and tokenizing:   7%|▋         | 70/1000 [18:11<2:39:18, 10.28s/it]
# Generating labels and tokenizing:   7%|▋         | 71/1000 [18:17<2:25:02,  9.37s/it]
# Generating labels and tokenizing:   7%|▋         | 72/1000 [19:05<4:55:37, 19.11s/it]
# Generating labels and tokenizing:   7%|▋         | 74/1000 [19:32<4:16:43, 16.63s/it]
# Generating labels and tokenizing:   8%|▊         | 75/1000 [20:02<5:04:30, 19.75s/it]
# Generating labels and tokenizing:   8%|▊         | 76/1000 [20:08<4:10:41, 16.28s/it]
# Generating labels and tokenizing:   8%|▊         | 77/1000 [20:19<3:51:02, 15.02s/it]
# Generating labels and tokenizing:   8%|▊         | 78/1000 [20:24<3:09:47, 12.35s/it]
# Generating labels and tokenizing:   8%|▊         | 79/1000 [20:43<3:36:02, 14.07s/it]
# Generating labels and tokenizing:   8%|▊         | 80/1000 [20:53<3:19:14, 12.99s/it]
# Generating labels and tokenizing:   8%|▊         | 81/1000 [21:00<2:53:26, 11.32s/it]
# Generating labels and tokenizing:   8%|▊         | 82/1000 [21:18<3:20:04, 13.08s/it]
# Generating labels and tokenizing:   8%|▊         | 83/1000 [21:46<4:29:31, 17.63s/it]
# Generating labels and tokenizing:   8%|▊         | 84/1000 [22:14<5:15:49, 20.69s/it]
# Generating labels and tokenizing:   8%|▊         | 85/1000 [22:35<5:17:27, 20.82s/it]
# Generating labels and tokenizing:   9%|▊         | 87/1000 [23:37<6:27:50, 25.49s/it]
# Generating labels and tokenizing:   9%|▉         | 88/1000 [24:06<6:40:57, 26.38s/it]
# Generating labels and tokenizing:   9%|▉         | 89/1000 [25:04<8:44:33, 34.55s/it]
# Generating labels and tokenizing:   9%|▉         | 90/1000 [25:10<6:45:23, 26.73s/it]
# Generating labels and tokenizing:   9%|▉         | 91/1000 [25:31<6:23:35, 25.32s/it]
# Generating labels and tokenizing:   9%|▉         | 93/1000 [25:39<3:59:03, 15.81s/it]
# Generating labels and tokenizing:   9%|▉         | 94/1000 [26:00<4:18:12, 17.10s/it]
# Generating labels and tokenizing:  10%|▉         | 95/1000 [26:19<4:21:56, 17.37s/it]
# Generating labels and tokenizing:  10%|▉         | 96/1000 [26:45<4:57:36, 19.75s/it]
# Generating labels and tokenizing:  10%|▉         | 97/1000 [27:08<5:11:05, 20.67s/it]
# Generating labels and tokenizing:  10%|▉         | 98/1000 [27:17<4:22:35, 17.47s/it]
# Generating labels and tokenizing:  10%|█         | 100/1000 [27:38<3:34:23, 14.29s/it]
# Generating labels and tokenizing:  10%|█         | 101/1000 [27:56<3:49:17, 15.30s/it]
# Generating labels and tokenizing:  10%|█         | 102/1000 [28:14<3:58:24, 15.93s/it]
# Generating labels and tokenizing:  10%|█         | 103/1000 [28:24<3:32:08, 14.19s/it]
# Generating labels and tokenizing:  10%|█         | 104/1000 [28:37<3:29:52, 14.05s/it]
# Generating labels and tokenizing:  10%|█         | 105/1000 [29:04<4:23:33, 17.67s/it]
# Generating labels and tokenizing:  11%|█         | 106/1000 [29:19<4:11:27, 16.88s/it]
# Generating labels and tokenizing:  11%|█         | 107/1000 [29:29<3:42:56, 14.98s/it]
# Generating labels and tokenizing:  11%|█         | 108/1000 [29:39<3:17:41, 13.30s/it]
# Generating labels and tokenizing:  11%|█         | 109/1000 [29:55<3:29:46, 14.13s/it]
# Generating labels and tokenizing:  11%|█         | 110/1000 [30:06<3:14:48, 13.13s/it]
# Generating labels and tokenizing:  11%|█         | 111/1000 [30:19<3:16:52, 13.29s/it]
# Generating labels and tokenizing:  11%|█         | 112/1000 [30:37<3:37:00, 14.66s/it]
# Generating labels and tokenizing:  11%|█▏        | 114/1000 [30:51<2:45:36, 11.21s/it]
# Generating labels and tokenizing:  12%|█▏        | 115/1000 [31:10<3:11:52, 13.01s/it]
# Generating labels and tokenizing:  12%|█▏        | 116/1000 [31:19<2:57:06, 12.02s/it]
# Generating labels and tokenizing:  12%|█▏        | 118/1000 [31:49<3:16:02, 13.34s/it]
# Generating labels and tokenizing:  12%|█▏        | 120/1000 [31:53<2:11:45,  8.98s/it]
# Generating labels and tokenizing:  12%|█▏        | 121/1000 [32:28<3:32:47, 14.53s/it]
# Generating labels and tokenizing:  12%|█▏        | 122/1000 [33:00<4:32:30, 18.62s/it]
# Generating labels and tokenizing:  12%|█▏        | 124/1000 [33:26<3:58:48, 16.36s/it]
# Generating labels and tokenizing:  12%|█▎        | 125/1000 [33:38<3:45:37, 15.47s/it]
# Generating labels and tokenizing:  13%|█▎        | 126/1000 [33:58<4:01:24, 16.57s/it]
# Generating labels and tokenizing:  13%|█▎        | 127/1000 [34:03<3:15:14, 13.42s/it]
# Generating labels and tokenizing:  13%|█▎        | 129/1000 [34:10<2:15:34,  9.34s/it]
# Generating labels and tokenizing:  13%|█▎        | 130/1000 [34:31<2:53:52, 11.99s/it]
# Generating labels and tokenizing:  13%|█▎        | 131/1000 [34:55<3:36:06, 14.92s/it]
# Generating labels and tokenizing:  13%|█▎        | 132/1000 [35:11<3:40:59, 15.28s/it]
# Generating labels and tokenizing:  13%|█▎        | 133/1000 [35:35<4:16:01, 17.72s/it]
# Generating labels and tokenizing:  14%|█▎        | 135/1000 [35:42<2:44:34, 11.42s/it]
# Generating labels and tokenizing:  14%|█▎        | 136/1000 [35:59<3:05:19, 12.87s/it]
# Generating labels and tokenizing:  14%|█▎        | 137/1000 [36:14<3:09:40, 13.19s/it]
# Generating labels and tokenizing:  14%|█▍        | 138/1000 [36:22<2:49:30, 11.80s/it]
# Generating labels and tokenizing:  14%|█▍        | 139/1000 [36:44<3:32:22, 14.80s/it]
# Generating labels and tokenizing:  14%|█▍        | 140/1000 [37:10<4:16:13, 17.88s/it]
# Generating labels and tokenizing:  14%|█▍        | 141/1000 [37:21<3:48:12, 15.94s/it]
# Generating labels and tokenizing:  14%|█▍        | 142/1000 [37:27<3:05:39, 12.98s/it]
# Generating labels and tokenizing:  14%|█▍        | 143/1000 [37:56<4:12:16, 17.66s/it]
# Generating labels and tokenizing:  14%|█▍        | 144/1000 [37:59<3:13:07, 13.54s/it]
# Generating labels and tokenizing:  14%|█▍        | 145/1000 [38:20<3:40:22, 15.46s/it]
# Generating labels and tokenizing:  15%|█▍        | 146/1000 [38:50<4:42:45, 19.87s/it]
# Generating labels and tokenizing:  15%|█▍        | 147/1000 [39:01<4:06:23, 17.33s/it]
# Generating labels and tokenizing:  15%|█▍        | 148/1000 [39:19<4:09:49, 17.59s/it]
# Generating labels and tokenizing:  15%|█▍        | 149/1000 [39:31<3:46:08, 15.94s/it]
# Generating labels and tokenizing:  15%|█▌        | 150/1000 [39:48<3:49:01, 16.17s/it]
# Generating labels and tokenizing:  15%|█▌        | 151/1000 [39:53<2:59:45, 12.70s/it]
# Generating labels and tokenizing:  15%|█▌        | 152/1000 [40:14<3:34:40, 15.19s/it]
# Generating labels and tokenizing:  15%|█▌        | 153/1000 [40:53<5:14:44, 22.30s/it]
# Generating labels and tokenizing:  15%|█▌        | 154/1000 [41:19<5:30:28, 23.44s/it]
# Generating labels and tokenizing:  16%|█▌        | 155/1000 [41:28<4:30:40, 19.22s/it]
# Generating labels and tokenizing:  16%|█▌        | 156/1000 [42:04<5:41:22, 24.27s/it]
# Generating labels and tokenizing:  16%|█▌        | 157/1000 [42:09<4:17:55, 18.36s/it]
# Generating labels and tokenizing:  16%|█▌        | 158/1000 [42:13<3:20:17, 14.27s/it]
# Generating labels and tokenizing:  16%|█▌        | 160/1000 [42:34<2:53:47, 12.41s/it]
# Generating labels and tokenizing:  16%|█▌        | 161/1000 [43:15<4:33:07, 19.53s/it]
# Generating labels and tokenizing:  16%|█▌        | 162/1000 [43:21<3:43:05, 15.97s/it]
# Generating labels and tokenizing:  16%|█▋        | 163/1000 [43:26<3:02:09, 13.06s/it]
# Generating labels and tokenizing:  16%|█▋        | 164/1000 [43:49<3:38:36, 15.69s/it]
# Generating labels and tokenizing:  16%|█▋        | 165/1000 [44:06<3:43:42, 16.07s/it]
# Generating labels and tokenizing:  17%|█▋        | 166/1000 [44:13<3:08:57, 13.59s/it]
# Generating labels and tokenizing:  17%|█▋        | 167/1000 [44:41<4:06:21, 17.75s/it]
# Generating labels and tokenizing:  17%|█▋        | 168/1000 [44:46<3:14:19, 14.01s/it]
# Generating labels and tokenizing:  17%|█▋        | 169/1000 [45:03<3:25:58, 14.87s/it]
# Generating labels and tokenizing:  17%|█▋        | 170/1000 [45:08<2:44:33, 11.90s/it]
# Generating labels and tokenizing:  17%|█▋        | 171/1000 [45:17<2:32:35, 11.04s/it]
# Generating labels and tokenizing:  17%|█▋        | 172/1000 [45:58<4:36:45, 20.05s/it]
# Generating labels and tokenizing:  17%|█▋        | 173/1000 [46:09<3:57:53, 17.26s/it]
# Generating labels and tokenizing:  17%|█▋        | 174/1000 [46:16<3:16:26, 14.27s/it]
# Generating labels and tokenizing:  18%|█▊        | 176/1000 [46:37<2:52:18, 12.55s/it]
# Generating labels and tokenizing:  18%|█▊        | 177/1000 [47:04<3:39:24, 16.00s/it]
# Generating labels and tokenizing:  18%|█▊        | 178/1000 [47:25<3:58:36, 17.42s/it]
# Generating labels and tokenizing:  18%|█▊        | 179/1000 [47:41<3:51:28, 16.92s/it]
# Generating labels and tokenizing:  18%|█▊        | 180/1000 [48:07<4:27:08, 19.55s/it]
# Generating labels and tokenizing:  18%|█▊        | 181/1000 [48:28<4:34:14, 20.09s/it]
# Generating labels and tokenizing:  18%|█▊        | 182/1000 [48:50<4:38:17, 20.41s/it]
# Generating labels and tokenizing:  18%|█▊        | 184/1000 [49:04<3:16:30, 14.45s/it]
# Generating labels and tokenizing:  19%|█▊        | 186/1000 [49:18<2:36:08, 11.51s/it]
# Generating labels and tokenizing:  19%|█▊        | 187/1000 [49:37<2:57:28, 13.10s/it]
# Generating labels and tokenizing:  19%|█▉        | 188/1000 [49:54<3:10:08, 14.05s/it]
# Generating labels and tokenizing:  19%|█▉        | 189/1000 [50:14<3:31:21, 15.64s/it]
# Generating labels and tokenizing:  19%|█▉        | 190/1000 [50:32<3:39:02, 16.22s/it]
# Generating labels and tokenizing:  19%|█▉        | 191/1000 [50:43<3:19:42, 14.81s/it]
# Generating labels and tokenizing:  19%|█▉        | 192/1000 [50:48<2:41:19, 11.98s/it]
# Generating labels and tokenizing:  19%|█▉        | 193/1000 [51:10<3:18:16, 14.74s/it]
# Generating labels and tokenizing:  19%|█▉        | 194/1000 [51:33<3:53:25, 17.38s/it]
# Generating labels and tokenizing:  20%|█▉        | 195/1000 [52:01<4:32:38, 20.32s/it]
# Generating labels and tokenizing:  20%|█▉        | 196/1000 [52:26<4:50:04, 21.65s/it]
# Generating labels and tokenizing:  20%|█▉        | 197/1000 [52:49<4:58:16, 22.29s/it]
# Generating labels and tokenizing:  20%|█▉        | 198/1000 [53:32<6:17:51, 28.27s/it]
# Generating labels and tokenizing:  20%|█▉        | 199/1000 [53:52<5:47:03, 26.00s/it]
# Generating labels and tokenizing:  20%|██        | 200/1000 [54:11<5:16:15, 23.72s/it]
# Generating labels and tokenizing:  20%|██        | 202/1000 [54:30<3:50:00, 17.29s/it]
# Generating labels and tokenizing:  20%|██        | 203/1000 [54:39<3:20:29, 15.09s/it]
# Generating labels and tokenizing:  20%|██        | 204/1000 [54:50<3:08:40, 14.22s/it]
# Generating labels and tokenizing:  21%|██        | 206/1000 [55:12<2:48:01, 12.70s/it]
# Generating labels and tokenizing:  21%|██        | 207/1000 [55:27<2:54:16, 13.19s/it]
# Generating labels and tokenizing:  21%|██        | 208/1000 [55:47<3:17:37, 14.97s/it]
# Generating labels and tokenizing:  21%|██        | 209/1000 [56:14<3:59:31, 18.17s/it]
# Generating labels and tokenizing:  21%|██        | 210/1000 [56:29<3:47:06, 17.25s/it]
# Generating labels and tokenizing:  21%|██        | 211/1000 [56:39<3:22:31, 15.40s/it]
# Generating labels and tokenizing:  21%|██        | 212/1000 [57:10<4:19:42, 19.77s/it]
# Generating labels and tokenizing:  21%|██▏       | 213/1000 [57:27<4:07:09, 18.84s/it]
# Generating labels and tokenizing:  21%|██▏       | 214/1000 [58:19<6:17:03, 28.78s/it]
# Generating labels and tokenizing:  22%|██▏       | 215/1000 [58:47<6:10:29, 28.32s/it]
# Generating labels and tokenizing:  22%|██▏       | 216/1000 [59:09<5:46:31, 26.52s/it]
# Generating labels and tokenizing:  22%|██▏       | 217/1000 [59:15<4:25:40, 20.36s/it]
# Generating labels and tokenizing:  22%|██▏       | 218/1000 [59:49<5:21:26, 24.66s/it]
# Generating labels and tokenizing:  22%|██▏       | 219/1000 [1:00:17<5:30:38, 25.40s/it]
# Generating labels and tokenizing:  22%|██▏       | 221/1000 [1:00:44<4:21:10, 20.12s/it]
# Generating labels and tokenizing:  22%|██▏       | 222/1000 [1:01:05<4:21:23, 20.16s/it]
# Generating labels and tokenizing:  22%|██▏       | 223/1000 [1:01:34<4:50:46, 22.45s/it]
# Generating labels and tokenizing:  22%|██▏       | 224/1000 [1:01:42<4:02:20, 18.74s/it]
# Generating labels and tokenizing:  22%|██▎       | 225/1000 [1:01:55<3:40:53, 17.10s/it]
# Generating labels and tokenizing:  23%|██▎       | 226/1000 [1:02:11<3:36:06, 16.75s/it]
# Generating labels and tokenizing:  23%|██▎       | 227/1000 [1:02:46<4:44:26, 22.08s/it]
# Generating labels and tokenizing:  23%|██▎       | 228/1000 [1:02:59<4:08:52, 19.34s/it]
# Generating labels and tokenizing:  23%|██▎       | 229/1000 [1:03:25<4:34:08, 21.33s/it]
# Generating labels and tokenizing:  23%|██▎       | 230/1000 [1:03:41<4:11:33, 19.60s/it]
# Generating labels and tokenizing:  23%|██▎       | 231/1000 [1:03:55<3:51:55, 18.10s/it]
# Generating labels and tokenizing:  23%|██▎       | 232/1000 [1:04:07<3:28:21, 16.28s/it]
# Generating labels and tokenizing:  23%|██▎       | 233/1000 [1:04:34<4:06:23, 19.27s/it]
# Generating labels and tokenizing:  23%|██▎       | 234/1000 [1:05:04<4:50:00, 22.72s/it]
# Generating labels and tokenizing:  24%|██▎       | 236/1000 [1:05:22<3:28:09, 16.35s/it]
# Generating labels and tokenizing:  24%|██▎       | 237/1000 [1:05:55<4:18:53, 20.36s/it]
# Generating labels and tokenizing:  24%|██▍       | 238/1000 [1:06:11<4:04:33, 19.26s/it]
# Generating labels and tokenizing:  24%|██▍       | 239/1000 [1:06:23<3:39:26, 17.30s/it]
# Generating labels and tokenizing:  24%|██▍       | 240/1000 [1:06:34<3:17:09, 15.56s/it]
# Generating labels and tokenizing:  24%|██▍       | 241/1000 [1:06:51<3:23:23, 16.08s/it]
# Generating labels and tokenizing:  24%|██▍       | 242/1000 [1:07:03<3:06:22, 14.75s/it]
# Generating labels and tokenizing:  24%|██▍       | 243/1000 [1:07:32<4:00:14, 19.04s/it]
# Generating labels and tokenizing:  24%|██▍       | 244/1000 [1:07:47<3:43:47, 17.76s/it]
# Generating labels and tokenizing:  24%|██▍       | 245/1000 [1:08:02<3:32:22, 16.88s/it]
# Generating labels and tokenizing:  25%|██▍       | 246/1000 [1:08:13<3:12:02, 15.28s/it]
# Generating labels and tokenizing:  25%|██▍       | 247/1000 [1:08:52<4:39:33, 22.28s/it]
# Generating labels and tokenizing:  25%|██▍       | 248/1000 [1:09:12<4:30:56, 21.62s/it]
# Generating labels and tokenizing:  25%|██▍       | 249/1000 [1:09:45<5:12:50, 24.99s/it]
# Generating labels and tokenizing:  25%|██▌       | 250/1000 [1:10:07<5:00:19, 24.03s/it]
# Generating labels and tokenizing:  25%|██▌       | 252/1000 [1:10:12<2:57:04, 14.20s/it]
# Generating labels and tokenizing:  25%|██▌       | 253/1000 [1:10:26<2:54:51, 14.05s/it]
# Generating labels and tokenizing:  25%|██▌       | 254/1000 [1:10:58<3:55:27, 18.94s/it]
# Generating labels and tokenizing:  26%|██▌       | 255/1000 [1:11:23<4:13:18, 20.40s/it]
# Generating labels and tokenizing:  26%|██▌       | 256/1000 [1:11:44<4:15:42, 20.62s/it]
# Generating labels and tokenizing:  26%|██▌       | 257/1000 [1:12:05<4:16:23, 20.70s/it]
# Generating labels and tokenizing:  26%|██▌       | 258/1000 [1:12:10<3:21:37, 16.30s/it]
# Generating labels and tokenizing:  26%|██▌       | 259/1000 [1:12:28<3:27:28, 16.80s/it]
# Generating labels and tokenizing:  26%|██▌       | 261/1000 [1:12:33<2:06:19, 10.26s/it]
# Generating labels and tokenizing:  26%|██▋       | 263/1000 [1:12:49<1:55:34,  9.41s/it]
# Generating labels and tokenizing:  26%|██▋       | 264/1000 [1:12:57<1:51:05,  9.06s/it]
# Generating labels and tokenizing:  26%|██▋       | 265/1000 [1:13:13<2:11:43, 10.75s/it]
# Generating labels and tokenizing:  27%|██▋       | 266/1000 [1:13:26<2:17:59, 11.28s/it]
# Generating labels and tokenizing:  27%|██▋       | 268/1000 [1:13:31<1:32:58,  7.62s/it]
# Generating labels and tokenizing:  27%|██▋       | 269/1000 [1:13:36<1:23:47,  6.88s/it]
# Generating labels and tokenizing:  27%|██▋       | 270/1000 [1:13:47<1:37:50,  8.04s/it]
# Generating labels and tokenizing:  27%|██▋       | 271/1000 [1:14:09<2:19:43, 11.50s/it]
# Generating labels and tokenizing:  27%|██▋       | 272/1000 [1:14:38<3:17:19, 16.26s/it]
# Generating labels and tokenizing:  27%|██▋       | 273/1000 [1:15:15<4:29:15, 22.22s/it]
# Generating labels and tokenizing:  27%|██▋       | 274/1000 [1:15:25<3:47:14, 18.78s/it]
# Generating labels and tokenizing:  28%|██▊       | 275/1000 [1:15:53<4:18:21, 21.38s/it]
# Generating labels and tokenizing:  28%|██▊       | 276/1000 [1:16:23<4:46:37, 23.75s/it]
# Generating labels and tokenizing:  28%|██▊       | 278/1000 [1:16:30<2:55:58, 14.62s/it]
# Generating labels and tokenizing:  28%|██▊       | 279/1000 [1:16:42<2:48:42, 14.04s/it]
# Generating labels and tokenizing:  28%|██▊       | 280/1000 [1:16:58<2:54:35, 14.55s/it]
# Generating labels and tokenizing:  28%|██▊       | 282/1000 [1:17:05<1:57:40,  9.83s/it]
# Generating labels and tokenizing:  28%|██▊       | 284/1000 [1:17:29<2:06:44, 10.62s/it]
# Generating labels and tokenizing:  28%|██▊       | 285/1000 [1:17:50<2:33:20, 12.87s/it]
# Generating labels and tokenizing:  29%|██▊       | 286/1000 [1:18:19<3:16:15, 16.49s/it]
# Generating labels and tokenizing:  29%|██▉       | 288/1000 [1:18:46<3:02:16, 15.36s/it]
# Generating labels and tokenizing:  29%|██▉       | 289/1000 [1:19:19<3:49:00, 19.33s/it]
# Generating labels and tokenizing:  29%|██▉       | 290/1000 [1:19:33<3:33:05, 18.01s/it]
# Generating labels and tokenizing:  29%|██▉       | 291/1000 [1:19:45<3:14:43, 16.48s/it]
# Generating labels and tokenizing:  29%|██▉       | 292/1000 [1:20:04<3:21:35, 17.08s/it]
# Generating labels and tokenizing:  29%|██▉       | 293/1000 [1:20:22<3:23:44, 17.29s/it]
# Generating labels and tokenizing:  29%|██▉       | 294/1000 [1:20:47<3:50:46, 19.61s/it]
# Generating labels and tokenizing:  30%|██▉       | 296/1000 [1:21:48<4:46:55, 24.45s/it]
# Generating labels and tokenizing:  30%|██▉       | 298/1000 [1:22:01<3:25:02, 17.52s/it]
# Generating labels and tokenizing:  30%|██▉       | 299/1000 [1:22:38<4:12:39, 21.63s/it]
# Generating labels and tokenizing:  30%|███       | 300/1000 [1:22:47<3:38:53, 18.76s/it]
# Generating labels and tokenizing:  30%|███       | 301/1000 [1:22:55<3:05:49, 15.95s/it]
# Generating labels and tokenizing:  30%|███       | 302/1000 [1:23:15<3:18:54, 17.10s/it]
# Generating labels and tokenizing:  30%|███       | 303/1000 [1:23:33<3:21:18, 17.33s/it]
# Generating labels and tokenizing:  30%|███       | 304/1000 [1:23:45<3:01:29, 15.65s/it]
# Generating labels and tokenizing:  30%|███       | 305/1000 [1:24:12<3:40:11, 19.01s/it]
# Generating labels and tokenizing:  31%|███       | 306/1000 [1:24:32<3:43:03, 19.28s/it]
# Generating labels and tokenizing:  31%|███       | 307/1000 [1:24:56<3:59:31, 20.74s/it]
# Generating labels and tokenizing:  31%|███       | 308/1000 [1:25:17<4:01:27, 20.94s/it]
# Generating labels and tokenizing:  31%|███       | 310/1000 [1:25:30<2:42:55, 14.17s/it]
# Generating labels and tokenizing:  31%|███       | 312/1000 [1:25:37<1:53:32,  9.90s/it]
# Generating labels and tokenizing:  31%|███▏      | 314/1000 [1:25:45<1:29:16,  7.81s/it]
# Generating labels and tokenizing:  32%|███▏      | 315/1000 [1:26:03<1:53:02,  9.90s/it]
# Generating labels and tokenizing:  32%|███▏      | 316/1000 [1:26:12<1:51:58,  9.82s/it]
# Generating labels and tokenizing:  32%|███▏      | 317/1000 [1:26:44<2:52:53, 15.19s/it]
# Generating labels and tokenizing:  32%|███▏      | 318/1000 [1:26:55<2:39:12, 14.01s/it]
# Generating labels and tokenizing:  32%|███▏      | 319/1000 [1:27:15<2:57:47, 15.66s/it]
# Generating labels and tokenizing:  32%|███▏      | 320/1000 [1:27:57<4:20:40, 23.00s/it]
# Generating labels and tokenizing:  32%|███▏      | 321/1000 [1:28:27<4:43:14, 25.03s/it]
# Generating labels and tokenizing:  32%|███▏      | 322/1000 [1:28:35<3:47:37, 20.14s/it]
# Generating labels and tokenizing:  32%|███▏      | 323/1000 [1:28:50<3:30:37, 18.67s/it]
# Generating labels and tokenizing:  32%|███▏      | 324/1000 [1:29:16<3:54:17, 20.80s/it]
# Generating labels and tokenizing:  32%|███▎      | 325/1000 [1:29:21<2:59:30, 15.96s/it]
# Generating labels and tokenizing:  33%|███▎      | 326/1000 [1:29:28<2:29:46, 13.33s/it]
# Generating labels and tokenizing:  33%|███▎      | 327/1000 [1:29:45<2:42:38, 14.50s/it]
# Generating labels and tokenizing:  33%|███▎      | 328/1000 [1:30:22<3:57:02, 21.16s/it]
# Generating labels and tokenizing:  33%|███▎      | 329/1000 [1:30:47<4:11:13, 22.46s/it]
# Generating labels and tokenizing:  33%|███▎      | 330/1000 [1:31:11<4:13:33, 22.71s/it]
# Generating labels and tokenizing:  33%|███▎      | 331/1000 [1:31:35<4:17:35, 23.10s/it]
# Generating labels and tokenizing:  33%|███▎      | 332/1000 [1:31:41<3:22:46, 18.21s/it]
# Generating labels and tokenizing:  33%|███▎      | 333/1000 [1:32:08<3:51:26, 20.82s/it]
# Generating labels and tokenizing:  33%|███▎      | 334/1000 [1:32:33<4:04:14, 22.00s/it]
# Generating labels and tokenizing:  34%|███▎      | 336/1000 [1:32:58<3:13:53, 17.52s/it]
# Generating labels and tokenizing:  34%|███▎      | 337/1000 [1:33:09<2:55:30, 15.88s/it]
# Generating labels and tokenizing:  34%|███▍      | 338/1000 [1:33:19<2:38:30, 14.37s/it]
# Generating labels and tokenizing:  34%|███▍      | 339/1000 [1:33:44<3:10:50, 17.32s/it]
# Generating labels and tokenizing:  34%|███▍      | 341/1000 [1:34:07<2:42:41, 14.81s/it]
# Generating labels and tokenizing:  34%|███▍      | 343/1000 [1:34:26<2:19:24, 12.73s/it]
# Generating labels and tokenizing:  34%|███▍      | 344/1000 [1:34:45<2:33:54, 14.08s/it]
# Generating labels and tokenizing:  35%|███▍      | 346/1000 [1:35:08<2:22:52, 13.11s/it]
# Generating labels and tokenizing:  35%|███▍      | 347/1000 [1:35:22<2:24:21, 13.26s/it]
# Generating labels and tokenizing:  35%|███▍      | 349/1000 [1:35:40<2:06:31, 11.66s/it]
# Generating labels and tokenizing:  35%|███▌      | 350/1000 [1:35:42<1:44:02,  9.60s/it]
# Generating labels and tokenizing:  35%|███▌      | 351/1000 [1:35:58<2:00:21, 11.13s/it]
# Generating labels and tokenizing:  35%|███▌      | 352/1000 [1:36:08<1:57:31, 10.88s/it]
# Generating labels and tokenizing:  35%|███▌      | 353/1000 [1:36:23<2:07:28, 11.82s/it]
# Generating labels and tokenizing:  35%|███▌      | 354/1000 [1:36:55<3:08:15, 17.48s/it]
# Generating labels and tokenizing:  36%|███▌      | 355/1000 [1:37:23<3:40:12, 20.48s/it]
# Generating labels and tokenizing:  36%|███▌      | 357/1000 [1:37:29<2:14:33, 12.56s/it]
# Generating labels and tokenizing:  36%|███▌      | 358/1000 [1:37:51<2:38:55, 14.85s/it]
# Generating labels and tokenizing:  36%|███▌      | 359/1000 [1:38:14<3:01:59, 17.04s/it]
# Generating labels and tokenizing:  36%|███▌      | 360/1000 [1:38:25<2:44:34, 15.43s/it]
# Generating labels and tokenizing:  36%|███▌      | 361/1000 [1:38:45<2:57:34, 16.67s/it]
# Generating labels and tokenizing:  36%|███▋      | 363/1000 [1:39:04<2:22:42, 13.44s/it]
# Generating labels and tokenizing:  36%|███▋      | 364/1000 [1:39:37<3:11:43, 18.09s/it]
# Generating labels and tokenizing:  37%|███▋      | 366/1000 [1:39:48<2:18:10, 13.08s/it]
# Generating labels and tokenizing:  37%|███▋      | 367/1000 [1:40:21<3:04:22, 17.48s/it]
# Generating labels and tokenizing:  37%|███▋      | 368/1000 [1:40:40<3:09:17, 17.97s/it]
# Generating labels and tokenizing:  37%|███▋      | 369/1000 [1:40:49<2:43:57, 15.59s/it]
# Generating labels and tokenizing:  37%|███▋      | 370/1000 [1:40:56<2:19:38, 13.30s/it]
# Generating labels and tokenizing:  37%|███▋      | 371/1000 [1:41:35<3:33:50, 20.40s/it]
# Generating labels and tokenizing:  37%|███▋      | 373/1000 [1:42:14<3:28:34, 19.96s/it]
# Generating labels and tokenizing:  37%|███▋      | 374/1000 [1:42:31<3:21:35, 19.32s/it]
# Generating labels and tokenizing:  38%|███▊      | 375/1000 [1:42:48<3:14:31, 18.67s/it]
# Generating labels and tokenizing:  38%|███▊      | 376/1000 [1:43:11<3:28:15, 20.02s/it]
# Generating labels and tokenizing:  38%|███▊      | 377/1000 [1:43:25<3:09:49, 18.28s/it]
# Generating labels and tokenizing:  38%|███▊      | 378/1000 [1:43:32<2:37:15, 15.17s/it]
# Generating labels and tokenizing:  38%|███▊      | 379/1000 [1:44:06<3:31:00, 20.39s/it]
# Generating labels and tokenizing:  38%|███▊      | 380/1000 [1:44:28<3:35:31, 20.86s/it]
# Generating labels and tokenizing:  38%|███▊      | 381/1000 [1:44:59<4:05:10, 23.76s/it]
# Generating labels and tokenizing:  38%|███▊      | 382/1000 [1:45:07<3:17:27, 19.17s/it]
# Generating labels and tokenizing:  38%|███▊      | 383/1000 [1:45:24<3:11:20, 18.61s/it]
# Generating labels and tokenizing:  38%|███▊      | 384/1000 [1:45:31<2:33:54, 14.99s/it]
# Generating labels and tokenizing:  38%|███▊      | 385/1000 [1:45:59<3:14:06, 18.94s/it]
# Generating labels and tokenizing:  39%|███▊      | 387/1000 [1:46:18<2:30:23, 14.72s/it]
# Generating labels and tokenizing:  39%|███▉      | 388/1000 [1:46:42<2:52:22, 16.90s/it]
# Generating labels and tokenizing:  39%|███▉      | 389/1000 [1:46:49<2:26:52, 14.42s/it]
# Generating labels and tokenizing:  39%|███▉      | 391/1000 [1:46:58<1:42:02, 10.05s/it]
# Generating labels and tokenizing:  39%|███▉      | 392/1000 [1:47:07<1:41:08,  9.98s/it]
# Generating labels and tokenizing:  39%|███▉      | 393/1000 [1:47:12<1:27:58,  8.70s/it]
# Generating labels and tokenizing:  39%|███▉      | 394/1000 [1:47:29<1:48:57, 10.79s/it]
# Generating labels and tokenizing:  40%|███▉      | 395/1000 [1:47:46<2:06:24, 12.54s/it]
# Generating labels and tokenizing:  40%|███▉      | 396/1000 [1:47:53<1:50:46, 11.00s/it]
# Generating labels and tokenizing:  40%|███▉      | 397/1000 [1:48:08<2:01:20, 12.07s/it]
# Generating labels and tokenizing:  40%|███▉      | 398/1000 [1:48:25<2:16:17, 13.58s/it]
# Generating labels and tokenizing:  40%|███▉      | 399/1000 [1:48:52<2:54:12, 17.39s/it]
# Generating labels and tokenizing:  40%|████      | 400/1000 [1:49:15<3:11:57, 19.20s/it]
# Generating labels and tokenizing:  40%|████      | 401/1000 [1:49:33<3:08:31, 18.88s/it]
# Generating labels and tokenizing:  40%|████      | 402/1000 [1:49:50<3:00:17, 18.09s/it]
# Generating labels and tokenizing:  40%|████      | 403/1000 [1:49:59<2:35:23, 15.62s/it]
# Generating labels and tokenizing:  40%|████      | 404/1000 [1:50:11<2:22:35, 14.36s/it]
# Generating labels and tokenizing:  41%|████      | 406/1000 [1:50:28<1:57:02, 11.82s/it]
# Generating labels and tokenizing:  41%|████      | 408/1000 [1:51:05<2:22:27, 14.44s/it]
# Generating labels and tokenizing:  41%|████      | 409/1000 [1:51:35<2:56:22, 17.91s/it]
# Generating labels and tokenizing:  41%|████      | 410/1000 [1:51:40<2:24:22, 14.68s/it]
# Generating labels and tokenizing:  41%|████      | 411/1000 [1:52:02<2:43:07, 16.62s/it]
# Generating labels and tokenizing:  41%|████      | 412/1000 [1:52:55<4:18:59, 26.43s/it]
# Generating labels and tokenizing:  41%|████▏     | 413/1000 [1:53:16<4:03:17, 24.87s/it]
# Generating labels and tokenizing:  41%|████▏     | 414/1000 [1:53:44<4:11:37, 25.76s/it]
# Generating labels and tokenizing:  42%|████▏     | 415/1000 [1:54:03<3:51:28, 23.74s/it]
# Generating labels and tokenizing:  42%|████▏     | 416/1000 [1:54:51<4:58:55, 30.71s/it]
# Generating labels and tokenizing:  42%|████▏     | 418/1000 [1:55:21<3:50:17, 23.74s/it]
# Generating labels and tokenizing:  42%|████▏     | 419/1000 [1:55:40<3:36:47, 22.39s/it]
# Generating labels and tokenizing:  42%|████▏     | 420/1000 [1:56:10<3:55:34, 24.37s/it]
# Generating labels and tokenizing:  42%|████▏     | 421/1000 [1:56:20<3:19:27, 20.67s/it]
# Generating labels and tokenizing:  42%|████▏     | 423/1000 [1:56:49<2:52:31, 17.94s/it]
# Generating labels and tokenizing:  42%|████▏     | 424/1000 [1:57:08<2:53:38, 18.09s/it]
# Generating labels and tokenizing:  42%|████▎     | 425/1000 [1:57:27<2:55:37, 18.33s/it]
# Generating labels and tokenizing:  43%|████▎     | 426/1000 [1:57:41<2:44:20, 17.18s/it]
# Generating labels and tokenizing:  43%|████▎     | 427/1000 [1:58:03<2:57:09, 18.55s/it]
# Generating labels and tokenizing:  43%|████▎     | 428/1000 [1:58:14<2:36:33, 16.42s/it]
# Generating labels and tokenizing:  43%|████▎     | 429/1000 [1:58:22<2:13:16, 14.00s/it]
# Generating labels and tokenizing:  43%|████▎     | 430/1000 [1:58:36<2:12:12, 13.92s/it]
# Generating labels and tokenizing:  43%|████▎     | 431/1000 [1:58:41<1:48:53, 11.48s/it]
# Generating labels and tokenizing:  43%|████▎     | 432/1000 [1:59:29<3:30:33, 22.24s/it]
# Generating labels and tokenizing:  43%|████▎     | 433/1000 [2:00:00<3:54:30, 24.82s/it]
# Generating labels and tokenizing:  43%|████▎     | 434/1000 [2:00:11<3:14:20, 20.60s/it]
# Generating labels and tokenizing:  44%|████▎     | 435/1000 [2:00:32<3:15:38, 20.78s/it]
# Generating labels and tokenizing:  44%|████▎     | 436/1000 [2:00:55<3:21:47, 21.47s/it]
# Generating labels and tokenizing:  44%|████▎     | 437/1000 [2:01:12<3:07:49, 20.02s/it]
# Generating labels and tokenizing:  44%|████▍     | 438/1000 [2:01:49<3:57:26, 25.35s/it]
# Generating labels and tokenizing:  44%|████▍     | 439/1000 [2:02:11<3:46:19, 24.21s/it]
# Generating labels and tokenizing:  44%|████▍     | 440/1000 [2:02:35<3:45:55, 24.21s/it]
# Generating labels and tokenizing:  44%|████▍     | 441/1000 [2:02:57<3:39:30, 23.56s/it]
# Generating labels and tokenizing:  44%|████▍     | 443/1000 [2:03:13<2:31:15, 16.29s/it]
# Generating labels and tokenizing:  44%|████▍     | 444/1000 [2:03:43<3:01:55, 19.63s/it]
# Generating labels and tokenizing:  44%|████▍     | 445/1000 [2:04:00<2:56:24, 19.07s/it]
# Generating labels and tokenizing:  45%|████▍     | 446/1000 [2:04:10<2:33:14, 16.60s/it]
# Generating labels and tokenizing:  45%|████▍     | 447/1000 [2:04:38<3:01:53, 19.73s/it]
# Generating labels and tokenizing:  45%|████▍     | 448/1000 [2:04:44<2:25:39, 15.83s/it]
# Generating labels and tokenizing:  45%|████▍     | 449/1000 [2:05:07<2:45:01, 17.97s/it]
# Generating labels and tokenizing:  45%|████▌     | 450/1000 [2:05:12<2:08:05, 13.97s/it]
# Generating labels and tokenizing:  45%|████▌     | 451/1000 [2:05:34<2:29:45, 16.37s/it]
# Generating labels and tokenizing:  45%|████▌     | 452/1000 [2:06:32<4:24:14, 28.93s/it]
# Generating labels and tokenizing:  45%|████▌     | 453/1000 [2:06:46<3:42:05, 24.36s/it]
# Generating labels and tokenizing:  46%|████▌     | 455/1000 [2:06:54<2:15:44, 14.94s/it]
# Generating labels and tokenizing:  46%|████▌     | 456/1000 [2:07:00<1:57:01, 12.91s/it]
# Generating labels and tokenizing:  46%|████▌     | 458/1000 [2:07:19<1:43:58, 11.51s/it]
# Generating labels and tokenizing:  46%|████▌     | 459/1000 [2:07:27<1:35:08, 10.55s/it]
# Generating labels and tokenizing:  46%|████▌     | 460/1000 [2:07:31<1:20:41,  8.97s/it]
# Generating labels and tokenizing:  46%|████▌     | 461/1000 [2:07:41<1:22:42,  9.21s/it]
# Generating labels and tokenizing:  46%|████▌     | 462/1000 [2:07:58<1:43:07, 11.50s/it]
# Generating labels and tokenizing:  46%|████▋     | 463/1000 [2:08:11<1:46:12, 11.87s/it]
# Generating labels and tokenizing:  46%|████▋     | 464/1000 [2:08:44<2:40:24, 17.96s/it]
# Generating labels and tokenizing:  46%|████▋     | 465/1000 [2:08:56<2:23:14, 16.06s/it]
# Generating labels and tokenizing:  47%|████▋     | 466/1000 [2:09:05<2:04:11, 13.95s/it]
# Generating labels and tokenizing:  47%|████▋     | 467/1000 [2:09:18<2:00:54, 13.61s/it]
# Generating labels and tokenizing:  47%|████▋     | 468/1000 [2:09:22<1:37:08, 10.96s/it]
# Generating labels and tokenizing:  47%|████▋     | 469/1000 [2:09:51<2:23:36, 16.23s/it]
# Generating labels and tokenizing:  47%|████▋     | 470/1000 [2:10:13<2:38:50, 17.98s/it]
# Generating labels and tokenizing:  47%|████▋     | 471/1000 [2:10:36<2:51:06, 19.41s/it]
# Generating labels and tokenizing:  47%|████▋     | 472/1000 [2:10:57<2:56:45, 20.09s/it]
# Generating labels and tokenizing:  47%|████▋     | 473/1000 [2:11:01<2:12:57, 15.14s/it]
# Generating labels and tokenizing:  47%|████▋     | 474/1000 [2:11:25<2:36:26, 17.85s/it]
# Generating labels and tokenizing:  48%|████▊     | 475/1000 [2:11:30<2:02:45, 14.03s/it]
# Generating labels and tokenizing:  48%|████▊     | 476/1000 [2:12:00<2:43:30, 18.72s/it]
# Generating labels and tokenizing:  48%|████▊     | 478/1000 [2:12:23<2:13:29, 15.34s/it]
# Generating labels and tokenizing:  48%|████▊     | 479/1000 [2:12:33<2:02:22, 14.09s/it]
# Generating labels and tokenizing:  48%|████▊     | 480/1000 [2:12:47<2:01:05, 13.97s/it]
# Generating labels and tokenizing:  48%|████▊     | 481/1000 [2:12:54<1:46:02, 12.26s/it]
# Generating labels and tokenizing:  48%|████▊     | 482/1000 [2:13:13<2:00:59, 14.01s/it]
# Generating labels and tokenizing:  48%|████▊     | 483/1000 [2:13:30<2:08:04, 14.86s/it]
# Generating labels and tokenizing:  48%|████▊     | 484/1000 [2:13:42<2:00:42, 14.04s/it]
# Generating labels and tokenizing:  48%|████▊     | 485/1000 [2:13:51<1:47:31, 12.53s/it]
# Generating labels and tokenizing:  49%|████▊     | 486/1000 [2:13:59<1:37:30, 11.38s/it]
# Generating labels and tokenizing:  49%|████▊     | 487/1000 [2:14:15<1:47:07, 12.53s/it]
# Generating labels and tokenizing:  49%|████▉     | 488/1000 [2:14:48<2:39:32, 18.70s/it]
# Generating labels and tokenizing:  49%|████▉     | 489/1000 [2:15:25<3:25:53, 24.17s/it]
# Generating labels and tokenizing:  49%|████▉     | 490/1000 [2:15:43<3:09:25, 22.28s/it]
# Generating labels and tokenizing:  49%|████▉     | 491/1000 [2:16:04<3:06:51, 22.03s/it]
# Generating labels and tokenizing:  49%|████▉     | 492/1000 [2:16:32<3:21:08, 23.76s/it]
# Generating labels and tokenizing:  49%|████▉     | 493/1000 [2:16:59<3:28:20, 24.65s/it]
# Generating labels and tokenizing:  49%|████▉     | 494/1000 [2:17:10<2:53:44, 20.60s/it]
# Generating labels and tokenizing:  50%|████▉     | 495/1000 [2:17:19<2:23:13, 17.02s/it]
# Generating labels and tokenizing:  50%|████▉     | 496/1000 [2:17:50<3:00:23, 21.47s/it]
# Generating labels and tokenizing:  50%|████▉     | 497/1000 [2:18:02<2:34:28, 18.43s/it]
# Generating labels and tokenizing:  50%|████▉     | 498/1000 [2:18:30<2:59:26, 21.45s/it]
# Generating labels and tokenizing:  50%|█████     | 500/1000 [2:18:37<1:49:30, 13.14s/it]
# Generating labels and tokenizing:  50%|█████     | 501/1000 [2:18:45<1:39:04, 11.91s/it]
# Generating labels and tokenizing:  50%|█████     | 502/1000 [2:18:53<1:29:14, 10.75s/it]
# Generating labels and tokenizing:  50%|█████     | 503/1000 [2:18:58<1:16:14,  9.20s/it]
# Generating labels and tokenizing:  50%|█████     | 505/1000 [2:19:13<1:10:27,  8.54s/it]
# Generating labels and tokenizing:  51%|█████     | 506/1000 [2:19:20<1:06:38,  8.09s/it]
# Generating labels and tokenizing:  51%|█████     | 507/1000 [2:19:56<2:05:34, 15.28s/it]
# Generating labels and tokenizing:  51%|█████     | 508/1000 [2:20:26<2:36:31, 19.09s/it]
# Generating labels and tokenizing:  51%|█████     | 509/1000 [2:20:46<2:38:52, 19.41s/it]
# Generating labels and tokenizing:  51%|█████     | 510/1000 [2:20:50<2:03:08, 15.08s/it]
# Generating labels and tokenizing:  51%|█████     | 511/1000 [2:21:04<1:59:47, 14.70s/it]
# Generating labels and tokenizing:  51%|█████     | 512/1000 [2:22:11<4:03:46, 29.97s/it]
# Generating labels and tokenizing:  51%|█████▏    | 513/1000 [2:22:29<3:34:57, 26.48s/it]
# Generating labels and tokenizing:  51%|█████▏    | 514/1000 [2:22:36<2:47:10, 20.64s/it]
# Generating labels and tokenizing:  52%|█████▏    | 515/1000 [2:22:44<2:15:29, 16.76s/it]
# Generating labels and tokenizing:  52%|█████▏    | 516/1000 [2:22:59<2:13:00, 16.49s/it]
# Generating labels and tokenizing:  52%|█████▏    | 517/1000 [2:23:18<2:18:52, 17.25s/it]
# Generating labels and tokenizing:  52%|█████▏    | 518/1000 [2:23:46<2:42:38, 20.25s/it]
# Generating labels and tokenizing:  52%|█████▏    | 519/1000 [2:23:58<2:23:06, 17.85s/it]
# Generating labels and tokenizing:  52%|█████▏    | 520/1000 [2:24:19<2:30:49, 18.85s/it]
# Generating labels and tokenizing:  52%|█████▏    | 521/1000 [2:24:36<2:26:44, 18.38s/it]
# Generating labels and tokenizing:  52%|█████▏    | 522/1000 [2:24:59<2:36:17, 19.62s/it]
# Generating labels and tokenizing:  52%|█████▏    | 524/1000 [2:25:31<2:22:16, 17.93s/it]
# Generating labels and tokenizing:  52%|█████▎    | 525/1000 [2:25:39<2:02:02, 15.41s/it]
# Generating labels and tokenizing:  53%|█████▎    | 527/1000 [2:26:09<2:01:31, 15.42s/it]
# Generating labels and tokenizing:  53%|█████▎    | 528/1000 [2:26:18<1:48:39, 13.81s/it]
# Generating labels and tokenizing:  53%|█████▎    | 529/1000 [2:27:07<2:57:26, 22.60s/it]
# Generating labels and tokenizing:  53%|█████▎    | 530/1000 [2:27:18<2:32:15, 19.44s/it]
# Generating labels and tokenizing:  53%|█████▎    | 531/1000 [2:27:23<2:01:25, 15.53s/it]
# Generating labels and tokenizing:  53%|█████▎    | 532/1000 [2:27:35<1:53:37, 14.57s/it]
# Generating labels and tokenizing:  53%|█████▎    | 533/1000 [2:27:51<1:56:08, 14.92s/it]
# Generating labels and tokenizing:  53%|█████▎    | 534/1000 [2:28:15<2:16:07, 17.53s/it]
# Generating labels and tokenizing:  54%|█████▎    | 535/1000 [2:28:21<1:49:46, 14.16s/it]
# Generating labels and tokenizing:  54%|█████▎    | 536/1000 [2:28:34<1:48:09, 13.99s/it]
# Generating labels and tokenizing:  54%|█████▎    | 537/1000 [2:28:56<2:04:34, 16.14s/it]
# Generating labels and tokenizing:  54%|█████▍    | 538/1000 [2:29:21<2:24:48, 18.81s/it]
# Generating labels and tokenizing:  54%|█████▍    | 539/1000 [2:29:29<1:59:54, 15.61s/it]
# Generating labels and tokenizing:  54%|█████▍    | 540/1000 [2:29:43<1:55:57, 15.13s/it]
# Generating labels and tokenizing:  54%|█████▍    | 542/1000 [2:30:12<1:54:11, 14.96s/it]
# Generating labels and tokenizing:  54%|█████▍    | 543/1000 [2:30:30<1:58:21, 15.54s/it]
# Generating labels and tokenizing:  54%|█████▍    | 544/1000 [2:30:36<1:39:42, 13.12s/it]
# Generating labels and tokenizing:  55%|█████▍    | 545/1000 [2:30:49<1:40:16, 13.22s/it]
# Generating labels and tokenizing:  55%|█████▍    | 546/1000 [2:31:04<1:43:23, 13.66s/it]
# Generating labels and tokenizing:  55%|█████▍    | 547/1000 [2:31:19<1:46:20, 14.08s/it]
# Generating labels and tokenizing:  55%|█████▍    | 548/1000 [2:31:29<1:36:53, 12.86s/it]
# Generating labels and tokenizing:  55%|█████▍    | 549/1000 [2:31:48<1:50:36, 14.72s/it]
# Generating labels and tokenizing:  55%|█████▌    | 550/1000 [2:32:04<1:52:25, 14.99s/it]
# Generating labels and tokenizing:  55%|█████▌    | 551/1000 [2:32:24<2:02:37, 16.39s/it]
# Generating labels and tokenizing:  55%|█████▌    | 552/1000 [2:32:48<2:21:05, 18.90s/it]
# Generating labels and tokenizing:  55%|█████▌    | 553/1000 [2:33:18<2:44:08, 22.03s/it]
# Generating labels and tokenizing:  55%|█████▌    | 554/1000 [2:33:34<2:31:39, 20.40s/it]
# Generating labels and tokenizing:  56%|█████▌    | 557/1000 [2:34:01<1:42:39, 13.90s/it]
# Generating labels and tokenizing:  56%|█████▌    | 559/1000 [2:34:17<1:27:30, 11.91s/it]
# Generating labels and tokenizing:  56%|█████▌    | 560/1000 [2:34:31<1:29:54, 12.26s/it]
# Generating labels and tokenizing:  56%|█████▌    | 561/1000 [2:35:13<2:17:56, 18.85s/it]
# Generating labels and tokenizing:  56%|█████▌    | 562/1000 [2:35:23<2:01:59, 16.71s/it]
# Generating labels and tokenizing:  56%|█████▋    | 563/1000 [2:35:47<2:14:41, 18.49s/it]
# Generating labels and tokenizing:  56%|█████▋    | 564/1000 [2:36:24<2:51:51, 23.65s/it]
# Generating labels and tokenizing:  56%|█████▋    | 565/1000 [2:36:31<2:18:05, 19.05s/it]
# Generating labels and tokenizing:  57%|█████▋    | 566/1000 [2:36:39<1:54:12, 15.79s/it]
# Generating labels and tokenizing:  57%|█████▋    | 567/1000 [2:36:46<1:35:51, 13.28s/it]
# Generating labels and tokenizing:  57%|█████▋    | 568/1000 [2:37:07<1:51:17, 15.46s/it]
# Generating labels and tokenizing:  57%|█████▋    | 569/1000 [2:37:25<1:56:34, 16.23s/it]
# Generating labels and tokenizing:  57%|█████▋    | 570/1000 [2:37:49<2:13:18, 18.60s/it]
# Generating labels and tokenizing:  57%|█████▋    | 572/1000 [2:38:02<1:32:45, 13.00s/it]
# Generating labels and tokenizing:  57%|█████▋    | 573/1000 [2:38:16<1:34:41, 13.31s/it]
# Generating labels and tokenizing:  57%|█████▋    | 574/1000 [2:38:24<1:24:09, 11.85s/it]
# Generating labels and tokenizing:  57%|█████▊    | 575/1000 [2:39:01<2:12:07, 18.65s/it]
# Generating labels and tokenizing:  58%|█████▊    | 576/1000 [2:39:23<2:19:43, 19.77s/it]
# Generating labels and tokenizing:  58%|█████▊    | 577/1000 [2:39:32<1:56:29, 16.52s/it]
# Generating labels and tokenizing:  58%|█████▊    | 579/1000 [2:40:11<2:05:16, 17.85s/it]
# Generating labels and tokenizing:  58%|█████▊    | 580/1000 [2:40:49<2:39:55, 22.85s/it]
# Generating labels and tokenizing:  58%|█████▊    | 581/1000 [2:40:56<2:10:30, 18.69s/it]
# Generating labels and tokenizing:  58%|█████▊    | 582/1000 [2:41:01<1:44:55, 15.06s/it]
# Generating labels and tokenizing:  58%|█████▊    | 584/1000 [2:41:15<1:20:14, 11.57s/it]
# Generating labels and tokenizing:  59%|█████▊    | 586/1000 [2:41:29<1:08:04,  9.87s/it]
# Generating labels and tokenizing:  59%|█████▊    | 587/1000 [2:41:46<1:18:19, 11.38s/it]
# Generating labels and tokenizing:  59%|█████▉    | 588/1000 [2:42:02<1:24:48, 12.35s/it]
# Generating labels and tokenizing:  59%|█████▉    | 589/1000 [2:42:17<1:29:26, 13.06s/it]
# Generating labels and tokenizing:  59%|█████▉    | 590/1000 [2:42:25<1:19:54, 11.69s/it]
# Generating labels and tokenizing:  59%|█████▉    | 591/1000 [2:42:31<1:09:43, 10.23s/it]
# Generating labels and tokenizing:  59%|█████▉    | 592/1000 [2:42:50<1:25:21, 12.55s/it]
# Generating labels and tokenizing:  59%|█████▉    | 593/1000 [2:43:17<1:54:24, 16.87s/it]
# Generating labels and tokenizing:  60%|█████▉    | 595/1000 [2:43:24<1:12:42, 10.77s/it]
# ...
# Generating labels and tokenizing:  24%|██▍       | 24/100 [06:16<16:26, 12.97s/it]
# Generating labels and tokenizing:  25%|██▌       | 25/100 [06:55<26:05, 20.87s/it]
# Generating labels and tokenizing:  26%|██▌       | 26/100 [07:23<28:12, 22.87s/it]
# Generating labels and tokenizing:  27%|██▋       | 27/100 [07:38<25:07, 20.65s/it]
# Generating labels and tokenizing:  28%|██▊       | 28/100 [07:51<22:06, 18.43s/it]
# Generating labels and tokenizing:  29%|██▉       | 29/100 [07:58<17:24, 14.71s/it]
# Generating labels and tokenizing:  30%|███       | 30/100 [08:16<18:26, 15.81s/it]
# Generating labels and tokenizing:  31%|███       | 31/100 [08:20<14:08, 12.29s/it]
# Generating labels and tokenizing:  32%|███▏      | 32/100 [08:41<17:03, 15.06s/it]
# Generating labels and tokenizing:  33%|███▎      | 33/100 [09:00<18:01, 16.14s/it]
# Generating labels and tokenizing:  34%|███▍      | 34/100 [09:17<17:52, 16.24s/it]
# Generating labels and tokenizing:  35%|███▌      | 35/100 [09:26<15:16, 14.10s/it]
# Generating labels and tokenizing:  36%|███▌      | 36/100 [09:46<17:03, 15.99s/it]
# Generating labels and tokenizing:  37%|███▋      | 37/100 [10:07<18:15, 17.39s/it]
# Generating labels and tokenizing:  38%|███▊      | 38/100 [10:23<17:31, 16.96s/it]
# Generating labels and tokenizing:  39%|███▉      | 39/100 [10:44<18:28, 18.17s/it]
# Generating labels and tokenizing:  40%|████      | 40/100 [11:10<20:32, 20.55s/it]
# Generating labels and tokenizing:  41%|████      | 41/100 [11:36<21:47, 22.16s/it]
# Generating labels and tokenizing:  42%|████▏     | 42/100 [11:52<19:33, 20.23s/it]
# Generating labels and tokenizing:  43%|████▎     | 43/100 [12:25<22:54, 24.12s/it]
# Generating labels and tokenizing:  44%|████▍     | 44/100 [12:30<17:22, 18.62s/it]
# Generating labels and tokenizing:  45%|████▌     | 45/100 [12:49<16:57, 18.49s/it]
# Generating labels and tokenizing:  46%|████▌     | 46/100 [12:54<13:03, 14.51s/it]
# Generating labels and tokenizing:  47%|████▋     | 47/100 [13:40<21:06, 23.90s/it]
# Generating labels and tokenizing:  48%|████▊     | 48/100 [13:56<18:39, 21.54s/it]
# Generating labels and tokenizing:  49%|████▉     | 49/100 [14:03<14:39, 17.24s/it]
# Generating labels and tokenizing:  50%|█████     | 50/100 [14:21<14:40, 17.61s/it]
# Generating labels and tokenizing:  51%|█████     | 51/100 [15:03<20:10, 24.70s/it]
# Generating labels and tokenizing:  52%|█████▏    | 52/100 [15:37<22:03, 27.57s/it]
# Generating labels and tokenizing:  53%|█████▎    | 53/100 [16:01<20:40, 26.39s/it]
# Generating labels and tokenizing:  54%|█████▍    | 54/100 [16:17<18:02, 23.54s/it]
# Generating labels and tokenizing:  55%|█████▌    | 55/100 [16:28<14:37, 19.50s/it]
# Generating labels and tokenizing:  56%|█████▌    | 56/100 [16:49<14:48, 20.20s/it]
# Generating labels and tokenizing:  57%|█████▋    | 57/100 [17:05<13:34, 18.94s/it]
# Generating labels and tokenizing:  58%|█████▊    | 58/100 [17:22<12:49, 18.31s/it]
# Generating labels and tokenizing:  59%|█████▉    | 59/100 [17:36<11:31, 16.87s/it]
# Generating labels and tokenizing:  60%|██████    | 60/100 [18:09<14:26, 21.67s/it]
# Generating labels and tokenizing:  61%|██████    | 61/100 [18:20<12:02, 18.53s/it]
# Generating labels and tokenizing:  62%|██████▏   | 62/100 [18:45<13:02, 20.59s/it]
# Generating labels and tokenizing:  63%|██████▎   | 63/100 [18:58<11:15, 18.27s/it]
# Generating labels and tokenizing:  64%|██████▍   | 64/100 [19:11<09:55, 16.53s/it]
# Generating labels and tokenizing:  65%|██████▌   | 65/100 [19:21<08:38, 14.82s/it]
# Generating labels and tokenizing:  66%|██████▌   | 66/100 [19:45<09:58, 17.60s/it]
# Generating labels and tokenizing:  67%|██████▋   | 67/100 [19:54<08:11, 14.89s/it]
# Generating labels and tokenizing:  68%|██████▊   | 68/100 [20:15<08:54, 16.72s/it]
# Generating labels and tokenizing:  69%|██████▉   | 69/100 [20:31<08:31, 16.49s/it]
# Generating labels and tokenizing:  70%|███████   | 70/100 [20:38<06:52, 13.75s/it]
# Generating labels and tokenizing:  71%|███████   | 71/100 [20:52<06:34, 13.60s/it]
# Generating labels and tokenizing:  72%|███████▏  | 72/100 [21:17<07:58, 17.08s/it]
# Generating labels and tokenizing:  73%|███████▎  | 73/100 [21:23<06:13, 13.82s/it]
# Generating labels and tokenizing:  74%|███████▍  | 74/100 [21:28<04:48, 11.11s/it]
# Generating labels and tokenizing:  75%|███████▌  | 75/100 [21:32<03:47,  9.10s/it]
# Generating labels and tokenizing:  76%|███████▌  | 76/100 [22:18<08:05, 20.24s/it]
# Generating labels and tokenizing:  77%|███████▋  | 77/100 [22:23<05:54, 15.42s/it]
# Generating labels and tokenizing:  78%|███████▊  | 78/100 [22:49<06:49, 18.62s/it]
# Generating labels and tokenizing:  79%|███████▉  | 79/100 [23:07<06:28, 18.49s/it]
# Generating labels and tokenizing:  80%|████████  | 80/100 [23:26<06:11, 18.58s/it]
# Generating labels and tokenizing:  81%|████████  | 81/100 [23:40<05:30, 17.38s/it]
# Generating labels and tokenizing:  82%|████████▏ | 82/100 [23:57<05:10, 17.26s/it]
# Generating labels and tokenizing:  83%|████████▎ | 83/100 [24:10<04:28, 15.81s/it]
# Generating labels and tokenizing:  84%|████████▍ | 84/100 [24:19<03:42, 13.89s/it]
# Generating labels and tokenizing:  85%|████████▌ | 85/100 [24:33<03:27, 13.87s/it]
# Generating labels and tokenizing:  86%|████████▌ | 86/100 [24:47<03:13, 13.85s/it]
# Generating labels and tokenizing:  87%|████████▋ | 87/100 [25:22<04:23, 20.28s/it]
# Generating labels and tokenizing:  88%|████████▊ | 88/100 [25:37<03:45, 18.75s/it]
# Generating labels and tokenizing:  89%|████████▉ | 89/100 [25:49<03:01, 16.54s/it]
# Generating labels and tokenizing:  90%|█████████ | 90/100 [26:01<02:32, 15.26s/it]
# Generating labels and tokenizing:  91%|█████████ | 91/100 [26:09<01:59, 13.25s/it]
# Generating labels and tokenizing:  92%|█████████▏| 92/100 [26:20<01:40, 12.62s/it]
# Generating labels and tokenizing:  93%|█████████▎| 93/100 [26:30<01:22, 11.79s/it]
# Generating labels and tokenizing:  94%|█████████▍| 94/100 [27:01<01:44, 17.50s/it]
# Generating labels and tokenizing:  95%|█████████▌| 95/100 [27:06<01:08, 13.72s/it]
# Generating labels and tokenizing:  96%|█████████▌| 96/100 [27:15<00:49, 12.41s/it]
# Generating labels and tokenizing:  97%|█████████▋| 97/100 [28:03<01:08, 22.97s/it]
# Generating labels and tokenizing:  98%|█████████▊| 98/100 [28:25<00:45, 22.66s/it]
# Generating labels and tokenizing:  99%|█████████▉| 99/100 [28:31<00:17, 17.68s/it]
# Generating labels and tokenizing: 100%|██████████| 100/100 [29:01<00:00, 17.42s/it]
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# Generating labels and tokenizing:   0%|          | 0/100 [00:00<?, ?it/s]
# Generating labels and tokenizing:   1%|          | 1/100 [00:29<48:53, 29.63s/it]
# Generating labels and tokenizing:   2%|▏         | 2/100 [00:53<42:52, 26.25s/it]
# Generating labels and tokenizing:   3%|▎         | 3/100 [01:17<40:24, 24.99s/it]
# Generating labels and tokenizing:   4%|▍         | 4/100 [01:39<38:39, 24.16s/it]
# Generating labels and tokenizing:   5%|▌         | 5/100 [02:03<37:53, 23.93s/it]
# Generating labels and tokenizing:   6%|▌         | 6/100 [02:08<27:25, 17.51s/it]
# Generating labels and tokenizing:   7%|▋         | 7/100 [02:20<24:24, 15.75s/it]
# Generating labels and tokenizing:   8%|▊         | 8/100 [02:48<30:12, 19.71s/it]
# Generating labels and tokenizing:   9%|▉         | 9/100 [03:06<28:51, 19.02s/it]
# Generating labels and tokenizing:  10%|█         | 10/100 [03:37<34:08, 22.76s/it]
# Generating labels and tokenizing:  11%|█         | 11/100 [03:43<26:18, 17.74s/it]
# Generating labels and tokenizing:  12%|█▏        | 12/100 [04:00<25:39, 17.49s/it]
# Generating labels and tokenizing:  13%|█▎        | 13/100 [04:27<29:34, 20.40s/it]
# Generating labels and tokenizing:  14%|█▍        | 14/100 [04:44<27:39, 19.29s/it]
# Generating labels and tokenizing:  15%|█▌        | 15/100 [04:58<25:06, 17.72s/it]
# Generating labels and tokenizing:  16%|█▌        | 16/100 [05:12<23:07, 16.52s/it]
# Generating labels and tokenizing:  17%|█▋        | 17/100 [05:38<26:57, 19.48s/it]
# Generating labels and tokenizing:  18%|█▊        | 18/100 [05:45<21:23, 15.65s/it]
# Generating labels and tokenizing:  19%|█▉        | 19/100 [06:10<24:53, 18.44s/it]
# Generating labels and tokenizing:  20%|██        | 20/100 [06:16<19:40, 14.76s/it]
# Generating labels and tokenizing:  21%|██        | 21/100 [06:36<21:20, 16.20s/it]
# Generating labels and tokenizing:  22%|██▏       | 22/100 [06:52<21:08, 16.26s/it]
# Generating labels and tokenizing:  23%|██▎       | 23/100 [07:10<21:36, 16.83s/it]
# Generating labels and tokenizing:  24%|██▍       | 24/100 [07:38<25:25, 20.07s/it]
# Generating labels and tokenizing:  25%|██▌       | 25/100 [07:54<23:44, 19.00s/it]
# Generating labels and tokenizing:  26%|██▌       | 26/100 [08:19<25:32, 20.71s/it]
# Generating labels and tokenizing:  27%|██▋       | 27/100 [09:04<34:06, 28.04s/it]
# Generating labels and tokenizing:  28%|██▊       | 28/100 [09:26<31:25, 26.18s/it]
# Generating labels and tokenizing:  29%|██▉       | 29/100 [09:37<25:37, 21.65s/it]
# Generating labels and tokenizing:  30%|███       | 30/100 [10:11<29:23, 25.20s/it]
# Generating labels and tokenizing:  31%|███       | 31/100 [10:25<25:13, 21.94s/it]
# Generating labels and tokenizing:  32%|███▏      | 32/100 [10:37<21:30, 18.98s/it]
# Generating labels and tokenizing:  33%|███▎      | 33/100 [10:49<18:41, 16.75s/it]
# Generating labels and tokenizing:  34%|███▍      | 34/100 [11:03<17:39, 16.05s/it]
# Generating labels and tokenizing:  35%|███▌      | 35/100 [11:26<19:36, 18.10s/it]
# Generating labels and tokenizing:  36%|███▌      | 36/100 [11:35<16:31, 15.49s/it]
# Generating labels and tokenizing:  37%|███▋      | 37/100 [11:42<13:23, 12.75s/it]
# Generating labels and tokenizing:  38%|███▊      | 38/100 [11:50<11:51, 11.48s/it]
# Generating labels and tokenizing:  39%|███▉      | 39/100 [12:12<14:44, 14.50s/it]
# Generating labels and tokenizing:  40%|████      | 40/100 [12:27<14:45, 14.76s/it]
# Generating labels and tokenizing:  41%|████      | 41/100 [12:35<12:38, 12.85s/it]
# Generating labels and tokenizing:  42%|████▏     | 42/100 [12:56<14:37, 15.13s/it]
# Generating labels and tokenizing:  43%|████▎     | 43/100 [13:36<21:36, 22.74s/it]
# Generating labels and tokenizing:  44%|████▍     | 44/100 [13:48<18:07, 19.42s/it]
# Generating labels and tokenizing:  45%|████▌     | 45/100 [13:54<14:14, 15.54s/it]
# Generating labels and tokenizing:  46%|████▌     | 46/100 [14:21<17:04, 18.97s/it]
# Generating labels and tokenizing:  47%|████▋     | 47/100 [14:42<17:17, 19.57s/it]
# Generating labels and tokenizing:  48%|████▊     | 48/100 [14:56<15:17, 17.65s/it]
# Generating labels and tokenizing:  49%|████▉     | 49/100 [15:01<11:48, 13.89s/it]
# Generating labels and tokenizing:  50%|█████     | 50/100 [15:48<19:50, 23.81s/it]
# Generating labels and tokenizing:  51%|█████     | 51/100 [15:59<16:20, 20.02s/it]
# Generating labels and tokenizing:  52%|█████▏    | 52/100 [16:38<20:32, 25.68s/it]
# Generating labels and tokenizing:  53%|█████▎    | 53/100 [16:44<15:35, 19.90s/it]
# Generating labels and tokenizing:  54%|█████▍    | 54/100 [16:57<13:43, 17.90s/it]
# Generating labels and tokenizing:  55%|█████▌    | 55/100 [17:25<15:32, 20.72s/it]
# Generating labels and tokenizing:  56%|█████▌    | 56/100 [17:56<17:34, 23.96s/it]
# Generating labels and tokenizing:  57%|█████▋    | 57/100 [18:04<13:35, 18.97s/it]
# Generating labels and tokenizing:  58%|█████▊    | 58/100 [18:13<11:21, 16.23s/it]
# Generating labels and tokenizing:  59%|█████▉    | 59/100 [18:30<11:08, 16.31s/it]
# Generating labels and tokenizing:  60%|██████    | 60/100 [18:38<09:11, 13.79s/it]
# Generating labels and tokenizing:  61%|██████    | 61/100 [18:53<09:15, 14.24s/it]
# Generating labels and tokenizing:  62%|██████▏   | 62/100 [19:06<08:41, 13.74s/it]
# Generating labels and tokenizing:  63%|██████▎   | 63/100 [19:12<07:04, 11.47s/it]
# Generating labels and tokenizing:  64%|██████▍   | 64/100 [19:21<06:33, 10.93s/it]
# Generating labels and tokenizing:  65%|██████▌   | 65/100 [19:41<07:51, 13.48s/it]
# Generating labels and tokenizing:  66%|██████▌   | 66/100 [19:58<08:13, 14.51s/it]
# Generating labels and tokenizing:  67%|██████▋   | 67/100 [20:14<08:14, 15.00s/it]
# Generating labels and tokenizing:  68%|██████▊   | 68/100 [20:37<09:13, 17.30s/it]
# Generating labels and tokenizing:  69%|██████▉   | 69/100 [20:49<08:10, 15.82s/it]
# Generating labels and tokenizing:  70%|███████   | 70/100 [20:56<06:38, 13.29s/it]
# Generating labels and tokenizing:  71%|███████   | 71/100 [21:15<07:10, 14.84s/it]
# Generating labels and tokenizing:  72%|███████▏  | 72/100 [21:37<07:59, 17.13s/it]
# Generating labels and tokenizing:  73%|███████▎  | 73/100 [21:47<06:40, 14.83s/it]
# Generating labels and tokenizing:  74%|███████▍  | 74/100 [21:51<05:01, 11.58s/it]
# Generating labels and tokenizing:  75%|███████▌  | 75/100 [21:56<04:01,  9.65s/it]
# Generating labels and tokenizing:  76%|███████▌  | 76/100 [22:04<03:41,  9.22s/it]
# Generating labels and tokenizing:  77%|███████▋  | 77/100 [22:19<04:08, 10.81s/it]
# Generating labels and tokenizing:  78%|███████▊  | 78/100 [22:31<04:09, 11.34s/it]
# Generating labels and tokenizing:  79%|███████▉  | 79/100 [22:42<03:53, 11.11s/it]
# Generating labels and tokenizing:  80%|████████  | 80/100 [22:54<03:48, 11.41s/it]
# Generating labels and tokenizing:  81%|████████  | 81/100 [23:16<04:35, 14.51s/it]
# Generating labels and tokenizing:  82%|████████▏ | 82/100 [24:07<07:40, 25.59s/it]
# Generating labels and tokenizing:  83%|████████▎ | 83/100 [24:12<05:28, 19.34s/it]
# Generating labels and tokenizing:  84%|████████▍ | 84/100 [24:28<04:54, 18.40s/it]
# Generating labels and tokenizing:  85%|████████▌ | 85/100 [25:25<07:29, 29.97s/it]
# Generating labels and tokenizing:  86%|████████▌ | 86/100 [26:09<07:58, 34.19s/it]
# Generating labels and tokenizing:  87%|████████▋ | 87/100 [26:34<06:48, 31.42s/it]
# Generating labels and tokenizing:  88%|████████▊ | 88/100 [26:44<04:58, 24.87s/it]
# Generating labels and tokenizing:  89%|████████▉ | 89/100 [26:59<04:02, 22.03s/it]
# Generating labels and tokenizing:  90%|█████████ | 90/100 [27:20<03:38, 21.82s/it]
# Generating labels and tokenizing:  91%|█████████ | 91/100 [27:26<02:33, 17.06s/it]
# Generating labels and tokenizing:  92%|█████████▏| 92/100 [28:02<03:02, 22.77s/it]
# Generating labels and tokenizing:  93%|█████████▎| 93/100 [28:58<03:48, 32.61s/it]
# Generating labels and tokenizing:  94%|█████████▍| 94/100 [29:09<02:36, 26.14s/it]
# Generating labels and tokenizing:  95%|█████████▌| 95/100 [29:20<01:47, 21.51s/it]
# Generating labels and tokenizing:  96%|█████████▌| 96/100 [29:39<01:23, 20.90s/it]
# Generating labels and tokenizing:  97%|█████████▋| 97/100 [29:58<01:00, 20.24s/it]
# Generating labels and tokenizing:  98%|█████████▊| 98/100 [30:27<00:45, 22.83s/it]
# Generating labels and tokenizing:  99%|█████████▉| 99/100 [30:41<00:20, 20.35s/it]
# Generating labels and tokenizing: 100%|██████████| 100/100 [30:54<00:00, 18.55s/it]
# Labels generated and sentences tokenized.
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask', 'global_attention_mask', 'labels'],
#         num_rows: 259432
#     })
#     validation: Dataset({
#         features: ['input_ids', 'attention_mask', 'global_attention_mask', 'labels'],
#         num_rows: 27214
#     })
#     test: Dataset({
#         features: ['input_ids', 'attention_mask', 'global_attention_mask', 'labels'],
#         num_rows: 28855
#     })
# })
#
# Saving processed dataset to: /content/drive/My Drive/longformer_processed_govreport
# Saving the dataset (0/4 shards):   0%|          | 0/259432 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/27214 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/28855 [00:00<?, ? examples/s]
# Processed dataset saved successfully!
# All expected dataset splits verified on disk.
#
# This script has completed the data preparation (tokenization and label generation).
# The processed dataset is saved to: /content/drive/My Drive/longformer_processed_govreport
# You can now use this dataset for training your Longformer model without regenerating labels.

# %% [markdown]
# #Step 1: Data preparation and label generation

# %%
import os
import torch
import numpy as np
from datasets import load_dataset, Dataset, DatasetDict
from transformers import LongformerTokenizer
import evaluate # Hugging Face's evaluate library for metrics
import nltk
from nltk.tokenize import sent_tokenize
from tqdm.auto import tqdm # For progress bars

# --- Install/Upgrade Libraries (Run this cell first in Colab) ---
# This ensures you have the latest compatible versions of transformers, datasets, and accelerate
# which are necessary for the TrainingArguments parameters used.
# !pip install --upgrade transformers datasets accelerate
# If the above line is commented out, uncomment it and run this cell.

# Ensure NLTK 'punkt' and 'punkt_tab' tokenizers are available for sentence splitting
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    print("Downloading 'punkt' NLTK data for sentence splitting...")
    nltk.download('punkt')
    print("'punkt' downloaded.")

try:
    # 'punkt_tab' is often used by ROUGE internally, especially with stemming
    nltk.data.find('tokenizers/punkt_tab/english.pickle')
except LookupError:
    print("Downloading 'punkt_tab' NLTK data for ROUGE evaluation...")
    nltk.download('punkt_tab')
    print("'punkt_tab' downloaded.")

# Ensure ROUGE metric is available
try:
    rouge_metric = evaluate.load("rouge")
except Exception:
    print("Downloading 'rouge' metric...")
    rouge_metric = evaluate.load("rouge")
    print("'rouge' loaded.")


# --- 0. Configuration ---
MODEL_NAME = "allenai/longformer-base-4096" # Base Longformer model for extractive summarization
# Path to your generated dataset with combined extractive summaries
GENERATED_DATASET_DIR = "./govreport_tfidf_vscode2"
# Directory where the processed (tokenized and labeled) dataset will be saved
PROCESSED_DATA_DIR = "./longformer_processed_govreport"
os.makedirs(PROCESSED_DATA_DIR, exist_ok=True)

# Max length for a single sentence input to LongformerForSequenceClassification
SENTENCE_MAX_LENGTH = 512

# --- 1. Load the Generated GovReport Dataset ---
print(f"Loading generated GovReport dataset from: {GENERATED_DATASET_DIR}")
try:
    data_files = {
        "train": os.path.join(GENERATED_DATASET_DIR, "train.json"),
        "validation": os.path.join(GENERATED_DATASET_DIR, "validation.json"),
        "test": os.path.join(GENERATED_DATASET_DIR, "test.json"),
    }

    govreport_data_splits = load_dataset("json", data_files=data_files)

    print("\nGovReport dataset loaded successfully!")
    print(govreport_data_splits)

    # --- IMPORTANT: Select a small subset for quick testing/debugging ---
    # For full dataset processing, comment out or adjust these lines.
    # Keep this active for initial runs to ensure the pipeline works.
    print("\nSelecting a small subset of the dataset for quick testing. Adjust or remove for full processing.")
    govreport_data_splits["train"] = govreport_data_splits["train"].select(range(100))
    govreport_data_splits["validation"] = govreport_data_splits["validation"].select(range(10))
    govreport_data_splits["test"] = govreport_data_splits["test"].select(range(10))
    print("Subset selected:")
    print(govreport_data_splits)
    # --- END SUBSET SELECTION ---

    # Ensure the required columns exist
    if "original_text" not in govreport_data_splits["train"].column_names or \
       "extractive_summary" not in govreport_data_splits["train"].column_names:
        raise ValueError("Dataset must contain 'original_text' and 'extractive_summary' columns.")
except Exception as e:
    print(f"\nError loading GovReport dataset from {GENERATED_DATASET_DIR}: {e}")
    print("Please ensure the directory exists and contains 'train.json', 'validation.json', 'test.json'.")
    exit()

# --- 2. Initialize Longformer Tokenizer ---
tokenizer = LongformerTokenizer.from_pretrained(MODEL_NAME)

# --- 3. Function to Generate Extractive Labels (Oracle Summaries) ---
def generate_extractive_labels(examples):
    """
    Generates extractive labels for each sentence in a document based on ROUGE-L
    overlap with the combined extractive summary.
    """
    processed_examples = {
        "input_ids": [],
        "attention_mask": [],
        "global_attention_mask": [],
        "labels": [],
    }

    # Iterate through each example in the batch
    for i in tqdm(range(len(examples["original_text"])), desc="Generating labels"):
        document_text = examples["original_text"][i]
        extractive_summary_reference = examples["extractive_summary"][i]

        if not document_text or not extractive_summary_reference:
            continue

        sentences = sent_tokenize(document_text)
        if not sentences:
            continue

        # Calculate ROUGE-L F1 for each sentence against the extractive summary reference
        sentence_rouge_scores = []
        for sent_idx, sentence in enumerate(sentences):
            processed_sent, processed_ref_summary = postprocess_text_for_rouge(
                [sentence], [extractive_summary_reference]
            )
            score = rouge_metric.compute(
                predictions=processed_sent,
                references=processed_ref_summary,
                rouge_types=["rougeL"],
                use_stemmer=True,
            )
            sentence_rouge_scores.append((score["rougeL"], sent_idx))

        # Sort sentences by ROUGE-L F1 score in descending order
        sentence_rouge_scores.sort(key=lambda x: x[0], reverse=True)

        ROUGE_THRESHOLD = 0.20 # Adjust this threshold based on desired summary density/quality
        labels_for_document = [0] * len(sentences)

        for score, sent_idx in sentence_rouge_scores:
            if score >= ROUGE_THRESHOLD:
                labels_for_document[sent_idx] = 1

        for sent_idx, sentence in enumerate(sentences):
            inputs = tokenizer(
                sentence,
                truncation=True,
                max_length=SENTENCE_MAX_LENGTH,
                padding="max_length",
                return_tensors="pt"
            )

            global_attention_mask = torch.zeros_like(inputs["input_ids"])
            global_attention_mask[:, 0] = 1

            processed_examples["input_ids"].append(inputs["input_ids"].squeeze(0).tolist())
            processed_examples["attention_mask"].append(inputs["attention_mask"].squeeze(0).tolist())
            processed_examples["global_attention_mask"].append(global_attention_mask.squeeze(0).tolist())
            processed_examples["labels"].append(labels_for_document[sent_idx])

    return processed_examples

# Helper for ROUGE (ensures consistent sentence splitting for metric calculation)
def postprocess_text_for_rouge(preds, labels):
    preds = [pred.strip() for pred in preds]
    labels = [label.strip() for label in labels]
    preds = ["\n".join(sent_tokenize(pred)) for pred in preds]
    labels = ["\n".join(sent_tokenize(label)) for label in labels]
    return preds, labels

# --- 4. Apply Label Generation to Dataset Splits ---
print("\nGenerating extractive labels for dataset splits (this may take a while)...")
original_column_names = govreport_data_splits["train"].column_names

tokenized_datasets = govreport_data_splits.map(
    generate_extractive_labels,
    batched=True,
    remove_columns=original_column_names,
    num_proc=os.cpu_count() if os.cpu_count() else 1
)
print("\nExtractive labels generated and tokenized.")
print(tokenized_datasets)

# --- 5. Save the Processed Dataset ---
print(f"\nSaving processed dataset to: {PROCESSED_DATA_DIR}")
tokenized_datasets.save_to_disk(PROCESSED_DATA_DIR)
print("Processed dataset saved successfully!")

# %% [markdown]
# #Step2 : Model training

# %%
import os
import torch
import numpy as np
from datasets import load_dataset, Dataset, DatasetDict, load_from_disk # Added load_from_disk
from transformers import (
    LongformerTokenizer,
    LongformerForSequenceClassification,
    TrainingArguments,
    Trainer,
)
import evaluate # Hugging Face's evaluate library for metrics
import nltk
from nltk.tokenize import sent_tokenize
from tqdm import tqdm # Direct import of tqdm
from collections import Counter # To calculate class weights
from sklearn.metrics import precision_recall_fscore_support, accuracy_score # For compute_metrics

# --- Install/Upgrade Libraries (Run this cell first in Colab) ---
# This ensures you have the latest compatible versions of transformers, datasets, and accelerate
# which are necessary for the TrainingArguments parameters used.
# !pip install --upgrade transformers datasets accelerate
# If the above line is commented out, uncomment it and run this cell.

# Ensure NLTK 'punkt' and 'punkt_tab' tokenizers are available for sentence splitting
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    print("Downloading 'punkt' NLTK data for sentence splitting...")
    nltk.download('punkt')
    print("'punkt' downloaded.")

try:
    # 'punkt_tab' is often used by ROUGE internally, especially with stemming
    nltk.data.find('tokenizers/punkt_tab/english.pickle')
except LookupError:
    print("Downloading 'punkt_tab' NLTK data for ROUGE evaluation...")
    nltk.download('punkt_tab')
    print("'punkt_tab' downloaded.")

# Ensure ROUGE metric is available
try:
    rouge_metric = evaluate.load("rouge")
except Exception:
    print("Downloading 'rouge' metric...")
    rouge_metric = evaluate.load("rouge")
    print("'rouge' loaded.")


# --- 0. Configuration ---
MODEL_NAME = "allenai/longformer-base-4096" # Base Longformer model for extractive summarization
OUTPUT_DIR = "./longformer_extractive_govreport"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Path to your raw dataset with combined extractive summaries (input for label generation)
GENERATED_DATASET_DIR = "./govreport_tfidf_vscode2"

# New: Path to store the processed (labeled and tokenized) dataset
PROCESSED_DATA_DIR = "/content/drive/My Drive/longformer_processed_govreport" # Ensure this is a Drive path for persistence
os.makedirs(PROCESSED_DATA_DIR, exist_ok=True)

# Max length for a single sentence input to LongformerForSequenceClassification
SENTENCE_MAX_LENGTH = 512

# --- 1. Load or Generate Processed Dataset ---
tokenized_datasets = None
govreport_data_splits = None # Initialize to None

# Check if processed dataset already exists on disk
if os.path.exists(PROCESSED_DATA_DIR) and \
   os.path.exists(os.path.join(PROCESSED_DATA_DIR, "train")) and \
   os.path.exists(os.path.join(PROCESSED_DATA_DIR, "validation")) and \
   os.path.exists(os.path.join(PROCESSED_DATA_DIR, "test")):
    print(f"Loading processed dataset from: {PROCESSED_DATA_DIR}")
    try:
        tokenized_datasets = DatasetDict.load_from_disk(PROCESSED_DATA_DIR)
        print("\nProcessed dataset loaded successfully!")
        print(tokenized_datasets)
    except Exception as e:
        print(f"\nError loading processed dataset from {PROCESSED_DATA_DIR}: {e}")
        print("Attempting to regenerate dataset as loading failed...")
        tokenized_datasets = None # Reset to trigger regeneration
else: # This block runs if processed data is NOT found, meaning we need to load raw and process
    # --- Load the Generated GovReport Dataset (RAW) ---
    print(f"Loading raw GovReport dataset from: {GENERATED_DATASET_DIR}")
    try:
        data_files = {
            "train": os.path.join(GENERATED_DATASET_DIR, "train.json"),
            "validation": os.path.join(GENERATED_DATASET_DIR, "validation.json"),
            "test": os.path.join(GENERATED_DATASET_DIR, "test.json"),
        }
        govreport_data_splits = load_dataset("json", data_files=data_files)
        print("\nRaw GovReport dataset loaded successfully!")
        print(govreport_data_splits)

        # --- IMPORTANT: Select a small subset for quick testing/debugging ---
        print("\nSelecting a small subset of the dataset for quick testing. Adjust or remove for full training.")
        govreport_data_splits["train"] = govreport_data_splits["train"].select(range(1000))
        govreport_data_splits["validation"] = govreport_data_splits["validation"].select(range(100))
        govreport_data_splits["test"] = govreport_data_splits["test"].select(range(100))
        print("Subset selected:")
        print(govreport_data_splits)
        # --- END SUBSET SELECTION ---

        # Ensure the required columns exist
        if "original_text" not in govreport_data_splits["train"].column_names or \
           "extractive_summary" not in govreport_data_splits["train"].column_names:
            raise ValueError("Dataset must contain 'original_text' and 'extractive_summary' columns.")
    except Exception as e:
        print(f"\nError loading raw GovReport dataset from {GENERATED_DATASET_DIR}: {e}")
        print("Please ensure the directory exists and contains 'train.json', 'validation.json', 'test.json'.")
        exit() # Exit if raw data loading fails

    # --- Initialize Longformer Tokenizer (needed for generate_extractive_labels) ---
    # This tokenizer is specifically for the data preprocessing step
    tokenizer_for_preprocessing = LongformerTokenizer.from_pretrained(MODEL_NAME)

    # --- 3. Function to Generate Extractive Labels (Oracle Summaries) ---
    def generate_extractive_labels(examples):
        """
        Generates extractive labels for each sentence in a document based on ROUGE-L
        overlap with the combined extractive summary.
        """
        processed_examples = {
            "input_ids": [],
            "attention_mask": [],
            "global_attention_mask": [],
            "labels": [],
        }

        for i in tqdm(range(len(examples["original_text"])), desc="Generating labels"):
            document_text = examples["original_text"][i]
            extractive_summary_reference = examples["extractive_summary"][i]

            if not document_text or not extractive_summary_reference:
                continue

            sentences = sent_tokenize(document_text)
            if not sentences:
                continue

            sentence_rouge_scores = []
            for sent_idx, sentence in enumerate(sentences):
                processed_sent, processed_ref_summary = postprocess_text_for_rouge(
                    [sentence], [extractive_summary_reference]
                )
                score = rouge_metric.compute(
                    predictions=processed_sent,
                    references=processed_ref_summary,
                    rouge_types=["rougeL"],
                    use_stemmer=True,
                )
                sentence_rouge_scores.append((score["rougeL"], sent_idx))

            sentence_rouge_scores.sort(key=lambda x: x[0], reverse=True)

            ROUGE_THRESHOLD = 0.20 # Adjust this threshold based on desired summary density/quality
            labels_for_document = [0] * len(sentences)

            for score, sent_idx in sentence_rouge_scores:
                if score >= ROUGE_THRESHOLD:
                    labels_for_document[sent_idx] = 1

            for sent_idx, sentence in enumerate(sentences):
                inputs = tokenizer_for_preprocessing( # Use the tokenizer defined for preprocessing
                    sentence,
                    truncation=True,
                    max_length=SENTENCE_MAX_LENGTH,
                    padding="max_length",
                    return_tensors="pt"
                )

                global_attention_mask = torch.zeros_like(inputs["input_ids"])
                global_attention_mask[:, 0] = 1

                processed_examples["input_ids"].append(inputs["input_ids"].squeeze(0).tolist())
                processed_examples["attention_mask"].append(inputs["attention_mask"].squeeze(0).tolist())
                processed_examples["global_attention_mask"].append(global_attention_mask.squeeze(0).tolist())
                processed_examples["labels"].append(labels_for_document[sent_idx])

        return processed_examples

    # Helper for ROUGE (ensures consistent sentence splitting for metric calculation)
    def postprocess_text_for_rouge(preds, labels):
        preds = [pred.strip() for pred in preds]
        labels = [label.strip() for label in labels]
        preds = ["\n".join(sent_tokenize(pred)) for pred in preds]
        labels = ["\n".join(sent_tokenize(label)) for label in labels]
        return preds, labels

    # --- 4. Apply Label Generation to Dataset Splits ---
    print("\nGenerating extractive labels for dataset splits (this may take a while)...")
    # This line is now safely inside the else block where govreport_data_splits is guaranteed to be defined
    original_column_names = govreport_data_splits["train"].column_names

    tokenized_datasets = govreport_data_splits.map(
        generate_extractive_labels,
        batched=True,
        remove_columns=original_column_names,
        num_proc=os.cpu_count() if os.cpu_count() else 1
    )
    print("\nExtractive labels generated and tokenized.")
    print(tokenized_datasets)

    # --- Save the Processed Dataset ---
    print(f"\nSaving processed dataset to: {PROCESSED_DATA_DIR}")
    tokenized_datasets.save_to_disk(PROCESSED_DATA_DIR)
    print("Processed dataset saved successfully!")

# Ensure tokenizer is initialized globally for the Trainer, regardless of data loading path
tokenizer = LongformerTokenizer.from_pretrained(MODEL_NAME)

# --- 5. Define Metrics for Training ---
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)

    precision, recall, f1, _ = precision_recall_fscore_support(
        labels, predictions, average='binary', pos_label=1, zero_division=0
    )
    accuracy = accuracy_score(labels, predictions)

    return {"accuracy": accuracy, "precision": precision, "recall": recall, "f1": f1}


# --- 6. Initialize LongformerForSequenceClassification Model ---
model = LongformerForSequenceClassification.from_pretrained(MODEL_NAME, num_labels=2)

# --- Calculate Class Weights for Imbalanced Data ---
train_labels = tokenized_datasets["train"]["labels"]
label_counts = Counter(train_labels)
num_class_0 = label_counts.get(0, 0)
num_class_1 = label_counts.get(1, 0)
total_samples = len(train_labels)

print(f"\nLabel distribution in training set: Class 0 (Non-summary): {num_class_0}, Class 1 (Summary): {num_class_1}")

if num_class_0 > 0 and num_class_1 > 0:
    weight_for_class_0 = total_samples / (2 * num_class_0)
    weight_for_class_1 = total_samples / (2 * num_class_1)
    class_weights = torch.tensor([weight_for_class_0, weight_for_class_1], dtype=torch.float)
    print(f"Calculated class weights: Class 0: {weight_for_class_0:.4f}, Class 1: {weight_for_class_1:.4f}")
else:
    print("Warning: One or both classes are missing in the training data. Using uniform weights.")
    class_weights = torch.tensor([1.0, 1.0], dtype=torch.float)


# Move class weights to the same device as the model
if torch.cuda.is_available():
    class_weights = class_weights.to("cuda")
    model.to("cuda")
    print("LongformerForSequenceClassification model and class weights moved to GPU.")
else:
    print("No GPU found, model and class weights running on CPU.")

# Override the default loss function to use class weights
class CustomTrainer(Trainer):
    # Updated signature to accept num_items_in_batch and other kwargs
    def compute_loss(self, model, inputs, return_outputs=False, num_items_in_batch=None, **kwargs):
        labels = inputs.pop("labels")
        outputs = model(**inputs)
        logits = outputs.logits
        loss_fct = torch.nn.CrossEntropyLoss(weight=class_weights)
        loss = loss_fct(logits.view(-1, self.model.config.num_labels), labels.view(-1))
        return (loss, outputs) if return_outputs else loss

# --- 7. Set up Training Arguments ---
training_args = TrainingArguments(
    output_dir=OUTPUT_DIR,
    num_train_epochs=3,
    per_device_train_batch_size=2,
    per_device_eval_batch_size=2,
    gradient_accumulation_steps=4,
    gradient_checkpointing=True,
    fp16=torch.cuda.is_available(), # Enable mixed precision training if GPU is available
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir=f"{OUTPUT_DIR}/logs",
    logging_steps=100,
    eval_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    metric_for_best_model="f1",
    greater_is_better=True,
    report_to="none",
)

# --- 8. Create Trainer ---
trainer = CustomTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)

# --- 9. Start Training ---
print("\nStarting Longformer extractive summarization training...")

# Check for existing checkpoints to resume from
last_checkpoint = None
if os.path.isdir(training_args.output_dir):
    checkpoints = [d for d in os.listdir(training_args.output_dir) if d.startswith("checkpoint-")]
    if checkpoints:
        last_checkpoint = os.path.join(training_args.output_dir, max(checkpoints, key=lambda x: int(x.split('-')[1])))
        print(f"Found existing checkpoint: {last_checkpoint}. Resuming training from here.")

trainer.train(resume_from_checkpoint=last_checkpoint)

print("\nTraining complete! Best model saved to:", trainer.state.best_model_checkpoint)

# --- 10. Evaluate on Test Set (Optional) ---
print("\nEvaluating on test set...")
test_results = trainer.evaluate(tokenized_datasets["test"])
print("Test Results:", test_results)
# Out:
# Downloading 'punkt' NLTK data for sentence splitting...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# 'punkt' downloaded.
# Downloading 'punkt_tab' NLTK data for ROUGE evaluation...
# 'punkt_tab' downloaded.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading builder script: 0.00B [00:00, ?B/s]
# Loading processed dataset from: /content/drive/My Drive/longformer_processed_govreport
#
# Processed dataset loaded successfully!
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask', 'global_attention_mask', 'labels'],
#         num_rows: 259432
#     })
#     validation: Dataset({
#         features: ['input_ids', 'attention_mask', 'global_attention_mask', 'labels'],
#         num_rows: 27214
#     })
#     test: Dataset({
#         features: ['input_ids', 'attention_mask', 'global_attention_mask', 'labels'],
#         num_rows: 28855
#     })
# })
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/694 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/597M [00:00<?, ?B/s]
# Some weights of LongformerForSequenceClassification were not initialized from the model checkpoint at allenai/longformer-base-4096 and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# model.safetensors:   0%|          | 0.00/597M [00:00<?, ?B/s]
# Label distribution in training set: Class 0 (Non-summary): 253686, Class 1 (Summary): 5746
# Calculated class weights: Class 0: 0.5113, Class 1: 22.5750
# LongformerForSequenceClassification model and class weights moved to GPU.
#
# Starting Longformer extractive summarization training...
# Found existing checkpoint: ./longformer_extractive_govreport/checkpoint-6268. Resuming training from here.
# /tmp/ipython-input-1781087401.py:288: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `CustomTrainer.__init__`. Use `processing_class` instead.
#   trainer = CustomTrainer(
#     <div>
#
#       <progress value='6843' max='97287' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 6843/97287 17:32 < 46:07:33, 0.54 it/s, Epoch 0.21/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1781087401.py in <cell line: 0>()
#     306         print(f"Found existing checkpoint: {last_checkpoint}. Resuming training from here.")
#     307
# --> 308 trainer.train(resume_from_checkpoint=last_checkpoint)
#     309
#     310 print("\nTraining complete! Best model saved to:", trainer.state.best_model_checkpoint)
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2235                 hf_hub_utils.enable_progress_bars()
#    2236         else:
# -> 2237             return inner_training_loop(
#    2238                 args=args,
#    2239                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2576                     )
#    2577                     with context():
# -> 2578                         tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2579
#    2580                     if (
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in training_step(***failed resolving arguments***)
#    3838                 kwargs["scale_wrt_gas"] = False
#    3839
# -> 3840             self.accelerator.backward(loss, **kwargs)
#    3841
#    3842             return loss.detach()
#
# /usr/local/lib/python3.11/dist-packages/accelerate/accelerator.py in backward(self, loss, **kwargs)
#    2572             return
#    2573         elif self.scaler is not None:
# -> 2574             self.scaler.scale(loss).backward(**kwargs)
#    2575         elif learning_rate is not None and self.has_lomo_optimizer:
#    2576             self.lomo_backward(loss, learning_rate)
#
# /usr/local/lib/python3.11/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     624                 inputs=inputs,
#     625             )
# --> 626         torch.autograd.backward(
#     627             self, gradient, retain_graph, create_graph, inputs=inputs
#     628         )
#
# /usr/local/lib/python3.11/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     345     # some Python versions print out the first line of a multi-line function
#     346     # calls in the traceback and some print out the last line
# --> 347     _engine_run_backward(
#     348         tensors,
#     349         grad_tensors_,
#
# /usr/local/lib/python3.11/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     821         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822     try:
# --> 823         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824             t_outputs, *args, **kwargs
#     825         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %% [markdown]
# #updated checkpointing model training

# %%
import os
import torch
import numpy as np
from datasets import load_dataset, Dataset, DatasetDict, load_from_disk # Added load_from_disk
from transformers import (
    LongformerTokenizer,
    LongformerForSequenceClassification,
    TrainingArguments,
    Trainer,
)
import evaluate # Hugging Face's evaluate library for metrics
import nltk
from nltk.tokenize import sent_tokenize
from tqdm import tqdm # Direct import of tqdm
from collections import Counter # To calculate class weights
from sklearn.metrics import precision_recall_fscore_support, accuracy_score # For compute_metrics

# --- Install/Upgrade Libraries (Run this cell first in Colab) ---
# This ensures you have the latest compatible versions of transformers, datasets, and accelerate
# which are necessary for the TrainingArguments parameters used.
# !pip install --upgrade transformers datasets accelerate
# If the above line is commented out, uncomment it and run this cell.

# Ensure NLTK 'punkt' and 'punkt_tab' tokenizers are available for sentence splitting
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    print("Downloading 'punkt' NLTK data for sentence splitting...")
    nltk.download('punkt')
    print("'punkt' downloaded.")

try:
    # 'punkt_tab' is often used by ROUGE internally, especially with stemming
    nltk.data.find('tokenizers/punkt_tab/english.pickle')
except LookupError:
    print("Downloading 'punkt_tab' NLTK data for ROUGE evaluation...")
    nltk.download('punkt_tab')
    print("'punkt_tab' downloaded.")

# Ensure ROUGE metric is available
try:
    rouge_metric = evaluate.load("rouge")
except Exception:
    print("Downloading 'rouge' metric...")
    rouge_metric = evaluate.load("rouge")
    print("'rouge' loaded.")


# --- 0. Configuration ---
MODEL_NAME = "allenai/longformer-base-4096" # Base Longformer model for extractive summarization
# IMPORTANT: Change OUTPUT_DIR to a Google Drive path for persistence
OUTPUT_DIR = "/content/drive/My Drive/longformer_extractive_govreport"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Path to your raw dataset with combined extractive summaries (input for label generation)
GENERATED_DATASET_DIR = "./govreport_tfidf_vscode2"

# New: Path to store the processed (labeled and tokenized) dataset
PROCESSED_DATA_DIR = "/content/drive/My Drive/longformer_processed_govreport" # Ensure this is a Drive path for persistence
os.makedirs(PROCESSED_DATA_DIR, exist_ok=True)

# Max length for a single sentence input to LongformerForSequenceClassification
SENTENCE_MAX_LENGTH = 512

# --- 1. Load or Generate Processed Dataset ---
tokenized_datasets = None
govreport_data_splits = None # Initialize to None

# Check if processed dataset already exists on disk
if os.path.exists(PROCESSED_DATA_DIR) and \
   os.path.exists(os.path.join(PROCESSED_DATA_DIR, "train")) and \
   os.path.exists(os.path.join(PROCESSED_DATA_DIR, "validation")) and \
   os.path.exists(os.path.join(PROCESSED_DATA_DIR, "test")):
    print(f"Loading processed dataset from: {PROCESSED_DATA_DIR}")
    try:
        tokenized_datasets = DatasetDict.load_from_disk(PROCESSED_DATA_DIR)
        print("\nProcessed dataset loaded successfully!")
        print(tokenized_datasets)
    except Exception as e:
        print(f"\nError loading processed dataset from {PROCESSED_DATA_DIR}: {e}")
        print("Attempting to regenerate dataset as loading failed...")
        tokenized_datasets = None # Reset to trigger regeneration
else: # This block runs if processed data is NOT found, meaning we need to load raw and process
    # --- Load the Generated GovReport Dataset (RAW) ---
    print(f"Loading raw GovReport dataset from: {GENERATED_DATASET_DIR}")
    try:
        data_files = {
            "train": os.path.join(GENERATED_DATASET_DIR, "train.json"),
            "validation": os.path.join(GENERATED_DATASET_DIR, "validation.json"),
            "test": os.path.join(GENERATED_DATASET_DIR, "test.json"),
        }
        govreport_data_splits = load_dataset("json", data_files=data_files)
        print("\nRaw GovReport dataset loaded successfully!")
        print(govreport_data_splits)

        # --- IMPORTANT: Select a small subset for quick testing/debugging ---
        print("\nSelecting a small subset of the dataset for quick testing. Adjust or remove for full training.")
        govreport_data_splits["train"] = govreport_data_splits["train"].select(range(1000))
        govreport_data_splits["validation"] = govreport_data_splits["validation"].select(range(100))
        govreport_data_splits["test"] = govreport_data_splits["test"].select(range(100))
        print("Subset selected:")
        print(govreport_data_splits)
        # --- END SUBSET SELECTION ---

        # Ensure the required columns exist
        if "original_text" not in govreport_data_splits["train"].column_names or \
           "extractive_summary" not in govreport_data_splits["train"].column_names:
            raise ValueError("Dataset must contain 'original_text' and 'extractive_summary' columns.")
    except Exception as e:
        print(f"\nError loading raw GovReport dataset from {GENERATED_DATASET_DIR}: {e}")
        print("Please ensure the directory exists and contains 'train.json', 'validation.json', 'test.json'.")
        exit() # Exit if raw data loading fails

    # --- Initialize Longformer Tokenizer (needed for generate_extractive_labels) ---
    # This tokenizer is specifically for the data preprocessing step
    tokenizer_for_preprocessing = LongformerTokenizer.from_pretrained(MODEL_NAME)

    # --- 3. Function to Generate Extractive Labels (Oracle Summaries) ---
    def generate_extractive_labels(examples):
        """
        Generates extractive labels for each sentence in a document based on ROUGE-L
        overlap with the combined extractive summary.
        """
        processed_examples = {
            "input_ids": [],
            "attention_mask": [],
            "global_attention_mask": [],
            "labels": [],
        }

        for i in tqdm(range(len(examples["original_text"])), desc="Generating labels"):
            document_text = examples["original_text"][i]
            extractive_summary_reference = examples["extractive_summary"][i]

            if not document_text or not extractive_summary_reference:
                continue

            sentences = sent_tokenize(document_text)
            if not sentences:
                continue

            sentence_rouge_scores = []
            for sent_idx, sentence in enumerate(sentences):
                processed_sent, processed_ref_summary = postprocess_text_for_rouge(
                    [sentence], [extractive_summary_reference]
                )
                score = rouge_metric.compute(
                    predictions=processed_sent,
                    references=processed_ref_summary,
                    rouge_types=["rougeL"],
                    use_stemmer=True,
                )
                sentence_rouge_scores.append((score["rougeL"], sent_idx))

            sentence_rouge_scores.sort(key=lambda x: x[0], reverse=True)

            ROUGE_THRESHOLD = 0.20 # Adjust this threshold based on desired summary density/quality
            labels_for_document = [0] * len(sentences)

            for score, sent_idx in sentence_rouge_scores:
                if score >= ROUGE_THRESHOLD:
                    labels_for_document[sent_idx] = 1

            for sent_idx, sentence in enumerate(sentences):
                inputs = tokenizer_for_preprocessing( # Use the tokenizer defined for preprocessing
                    sentence,
                    truncation=True,
                    max_length=SENTENCE_MAX_LENGTH,
                    padding="max_length",
                    return_tensors="pt"
                )

                global_attention_mask = torch.zeros_like(inputs["input_ids"])
                global_attention_mask[:, 0] = 1

                processed_examples["input_ids"].append(inputs["input_ids"].squeeze(0).tolist())
                processed_examples["attention_mask"].append(inputs["attention_mask"].squeeze(0).tolist())
                processed_examples["global_attention_mask"].append(global_attention_mask.squeeze(0).tolist())
                processed_examples["labels"].append(labels_for_document[sent_idx])

        return processed_examples

    # Helper for ROUGE (ensures consistent sentence splitting for metric calculation)
    def postprocess_text_for_rouge(preds, labels):
        preds = [pred.strip() for pred in preds]
        labels = [label.strip() for label in labels]
        preds = ["\n".join(sent_tokenize(pred)) for pred in preds]
        labels = ["\n".join(sent_tokenize(label)) for label in labels]
        return preds, labels

    # --- 4. Apply Label Generation to Dataset Splits ---
    print("\nGenerating extractive labels for dataset splits (this may take a while)...")
    # This line is now safely inside the else block where govreport_data_splits is guaranteed to be defined
    original_column_names = govreport_data_splits["train"].column_names

    tokenized_datasets = govreport_data_splits.map(
        generate_extractive_labels,
        batched=True,
        remove_columns=original_column_names,
        num_proc=os.cpu_count() if os.cpu_count() else 1
    )
    print("\nExtractive labels generated and tokenized.")
    print(tokenized_datasets)

    # --- Save the Processed Dataset ---
    print(f"\nSaving processed dataset to: {PROCESSED_DATA_DIR}")
    tokenized_datasets.save_to_disk(PROCESSED_DATA_DIR)
    print("Processed dataset saved successfully!")

# Ensure tokenizer is initialized globally for the Trainer, regardless of data loading path
tokenizer = LongformerTokenizer.from_pretrained(MODEL_NAME)

# --- 5. Define Metrics for Training ---
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)

    precision, recall, f1, _ = precision_recall_fscore_support(
        labels, predictions, average='binary', pos_label=1, zero_division=0
    )
    accuracy = accuracy_score(labels, predictions)

    return {"accuracy": accuracy, "precision": precision, "recall": recall, "f1": f1}


# --- 6. Initialize LongformerForSequenceClassification Model ---
model = LongformerForSequenceClassification.from_pretrained(MODEL_NAME, num_labels=2)

# --- Calculate Class Weights for Imbalanced Data ---
train_labels = tokenized_datasets["train"]["labels"]
label_counts = Counter(train_labels)
num_class_0 = label_counts.get(0, 0)
num_class_1 = label_counts.get(1, 0)
total_samples = len(train_labels)

print(f"\nLabel distribution in training set: Class 0 (Non-summary): {num_class_0}, Class 1 (Summary): {num_class_1}")

if num_class_0 > 0 and num_class_1 > 0:
    weight_for_class_0 = total_samples / (2 * num_class_0)
    weight_for_class_1 = total_samples / (2 * num_class_1)
    class_weights = torch.tensor([weight_for_class_0, weight_for_class_1], dtype=torch.float)
    print(f"Calculated class weights: Class 0: {weight_for_class_0:.4f}, Class 1: {weight_for_class_1:.4f}")
else:
    print("Warning: One or both classes are missing in the training data. Using uniform weights.")
    class_weights = torch.tensor([1.0, 1.0], dtype=torch.float)


# Move class weights to the same device as the model
if torch.cuda.is_available():
    class_weights = class_weights.to("cuda")
    model.to("cuda")
    print("LongformerForSequenceClassification model and class weights moved to GPU.")
else:
    print("No GPU found, model and class weights running on CPU.")

# Override the default loss function to use class weights
class CustomTrainer(Trainer):
    # Updated signature to accept num_items_in_batch and other kwargs
    def compute_loss(self, model, inputs, return_outputs=False, num_items_in_batch=None, **kwargs):
        labels = inputs.pop("labels")
        outputs = model(**inputs)
        logits = outputs.logits
        loss_fct = torch.nn.CrossEntropyLoss(weight=class_weights)
        loss = loss_fct(logits.view(-1, self.model.config.num_labels), labels.view(-1))
        return (loss, outputs) if return_outputs else loss

# --- 7. Set up Training Arguments ---
training_args = TrainingArguments(
    output_dir=OUTPUT_DIR,
    num_train_epochs=3,
    per_device_train_batch_size=2,
    per_device_eval_batch_size=2,
    gradient_accumulation_steps=4,
    gradient_checkpointing=True,
    fp16=torch.cuda.is_available(), # Enable mixed precision training if GPU is available
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir=f"{OUTPUT_DIR}/logs",
    logging_steps=100,
    eval_strategy="steps", # Evaluate based on steps
    save_strategy="steps", # Save checkpoints based on steps
    save_steps=50,        # Save every 50 training steps
    eval_steps=500,        # Evaluate every 50 training steps (match save_steps)
    save_total_limit=2, # Keep the last 2 checkpoints (current and previous)
    load_best_model_at_end=False, # CHANGED: Do NOT load best model based on metric
    # metric_for_best_model="f1", # REMOVED: No longer needed with load_best_model_at_end=False
    # greater_is_better=True,     # REMOVED: No longer needed
    report_to="none",
)

# --- 8. Create Trainer ---
trainer = CustomTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)

# --- 9. Start Training ---
print("\nStarting Longformer extractive summarization training...")

# Check for existing checkpoints to resume from
last_checkpoint = None
if os.path.isdir(training_args.output_dir):
    checkpoints = [d for d in os.listdir(training_args.output_dir) if d.startswith("checkpoint-")]
    if checkpoints:
        # Sort by step number to get the latest checkpoint (max number of steps completed)
        last_checkpoint = os.path.join(training_args.output_dir, max(checkpoints, key=lambda x: int(x.split('-')[1])))
        print(f"Found existing checkpoint: {last_checkpoint}. Resuming training from here.")

try:
    trainer.train(resume_from_checkpoint=last_checkpoint)
except Exception as e:
    print(f"Error during training or resuming: {e}")
    print("If this is an 'AttributeError: 'NoneType' object has no attribute 'load_state_dict'' related to fp16,")
    print("it might mean the previous checkpoint was saved inconsistently (e.g., GPU disconnected mid-save).")
    print(f"Consider deleting the '{OUTPUT_DIR}' folder manually and restarting training from scratch.")


print("\nTraining complete! Best model saved to:", trainer.state.best_model_checkpoint)

# --- 10. Evaluate on Test Set (Optional) ---
print("\nEvaluating on test set...")
test_results = trainer.evaluate(tokenized_datasets["test"])
print("Test Results:", test_results)
# Out:
# Downloading 'punkt_tab' NLTK data for ROUGE evaluation...
# 'punkt_tab' downloaded.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Loading processed dataset from: /content/drive/My Drive/longformer_processed_govreport
#
# Processed dataset loaded successfully!
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask', 'global_attention_mask', 'labels'],
#         num_rows: 259432
#     })
#     validation: Dataset({
#         features: ['input_ids', 'attention_mask', 'global_attention_mask', 'labels'],
#         num_rows: 27214
#     })
#     test: Dataset({
#         features: ['input_ids', 'attention_mask', 'global_attention_mask', 'labels'],
#         num_rows: 28855
#     })
# })
# Some weights of LongformerForSequenceClassification were not initialized from the model checkpoint at allenai/longformer-base-4096 and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Label distribution in training set: Class 0 (Non-summary): 253686, Class 1 (Summary): 5746
# Calculated class weights: Class 0: 0.5113, Class 1: 22.5750
# LongformerForSequenceClassification model and class weights moved to GPU.
# /tmp/ipython-input-1213008866.py:292: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `CustomTrainer.__init__`. Use `processing_class` instead.
#   trainer = CustomTrainer(
# Starting Longformer extractive summarization training...
# Found existing checkpoint: /content/drive/My Drive/longformer_extractive_govreport/checkpoint-6268. Resuming training from here.
# Warning: The following arguments do not match the ones in the `trainer_state.json` within the checkpoint directory:
# 	eval_steps: 50 (from args) != 500 (from trainer_state.json)
# 	save_steps: 50 (from args) != 500 (from trainer_state.json)
#     <div>
#
#       <progress value='8501' max='97287' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 8501/97287 3:29:24 < 138:53:24, 0.18 it/s, Epoch 0.26/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>6500</td>
#       <td>0.252900</td>
#       <td>0.121341</td>
#       <td>0.988278</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.230500</td>
#       <td>0.110604</td>
#       <td>0.988278</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.186000</td>
#       <td>0.123311</td>
#       <td>0.988278</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.126600</td>
#       <td>0.137786</td>
#       <td>0.988278</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='5028' max='13607' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 5028/13607 12:51 < 21:56, 6.52 it/s]
#     </div>

# %% [markdown]
# #Training with 500 -50-50 samples using BERTscore

# %%
import os
import torch
import numpy as np
from datasets import load_dataset, Dataset, DatasetDict, load_from_disk
from transformers import (
    LongformerTokenizer,
    LongformerForSequenceClassification,
    TrainingArguments,
    Trainer,
)
import evaluate
import nltk
from nltk.tokenize import sent_tokenize
from tqdm import tqdm
from collections import Counter
from sklearn.metrics import precision_recall_fscore_support, accuracy_score

# --- Install/Upgrade Libraries (Run this cell first in Colab) ---
# !pip install --upgrade transformers datasets accelerate
# !pip install bert-score

# Ensure NLTK 'punkt' and 'punkt_tab' tokenizers are available
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    print("Downloading 'punkt' NLTK data for sentence splitting...")
    nltk.download('punkt')
    print("'punkt' downloaded.")

try:
    nltk.data.find('tokenizers/punkt_tab/english.pickle')
except LookupError:
    print("Downloading 'punkt_tab' NLTK data for ROUGE evaluation...")
    nltk.download('punkt_tab')
    print("'punkt_tab' downloaded.")

try:
    bertscore_metric = evaluate.load("bertscore")
except Exception:
    print("Downloading 'bertscore' metric...")
    bertscore_metric = evaluate.load("bertscore")
    print("'bertscore' loaded.")


# --- 0. Configuration ---
MODEL_NAME = "allenai/longformer-base-4096"
OUTPUT_DIR = "/content/drive/My Drive/longformer_extractive_govreport"
os.makedirs(OUTPUT_DIR, exist_ok=True)
GENERATED_DATASET_DIR = "./govreport_tfidf_vscode2"
PROCESSED_DATA_DIR = "/content/drive/My Drive/longformer_processed_govreport"
os.makedirs(PROCESSED_DATA_DIR, exist_ok=True)
SENTENCE_MAX_LENGTH = 512

# --- IMPORTANT: FORCING A RERUN WITH NEW LABELS ---
# If you are changing the labeling metric (e.g., from ROUGE to BERTScore),
# you MUST delete the old processed dataset to force the script to re-label your data.
# Uncomment the line below to delete the old processed data directory.
# import shutil
# if os.path.exists(PROCESSED_DATA_DIR):
#    print(f"Deleting old processed dataset at: {PROCESSED_DATA_DIR}")
#    shutil.rmtree(PROCESSED_DATA_DIR)
#    print("Old processed dataset deleted. New one will be generated.")

# --- 1. Load or Generate Processed Dataset ---
tokenized_datasets = None
govreport_data_splits = None

if os.path.exists(PROCESSED_DATA_DIR) and \
   os.path.exists(os.path.join(PROCESSED_DATA_DIR, "train")) and \
   os.path.exists(os.path.join(PROCESSED_DATA_DIR, "validation")) and \
   os.path.exists(os.path.join(PROCESSED_DATA_DIR, "test")):
    print(f"Loading processed dataset from: {PROCESSED_DATA_DIR}")
    try:
        tokenized_datasets = DatasetDict.load_from_disk(PROCESSED_DATA_DIR)
        print("\nProcessed dataset loaded successfully!")
        print(tokenized_datasets)
    except Exception as e:
        print(f"\nError loading processed dataset from {PROCESSED_DATA_DIR}: {e}")
        print("Attempting to regenerate dataset as loading failed...")
        tokenized_datasets = None
else:
    print(f"Loading raw GovReport dataset from: {GENERATED_DATASET_DIR}")
    try:
        data_files = {
            "train": os.path.join(GENERATED_DATASET_DIR, "train.json"),
            "validation": os.path.join(GENERATED_DATA_DIR, "validation.json"),
            "test": os.path.join(GENERATED_DATA_DIR, "test.json"),
        }
        govreport_data_splits = load_dataset("json", data_files=data_files)
        print("\nRaw GovReport dataset loaded successfully!")
        print(govreport_data_splits)

        print("\nSelecting a small subset of the dataset for quick testing. Adjust or remove for full training.")
        govreport_data_splits["train"] = govreport_data_splits["train"].select(range(500))
        govreport_data_splits["validation"] = govreport_data_splits["validation"].select(range(50))
        govreport_data_splits["test"] = govreport_data_splits["test"].select(range(50))
        print("Subset selected:")
        print(govreport_data_splits)

        if "original_text" not in govreport_data_splits["train"].column_names or \
           "extractive_summary" not in govreport_data_splits["train"].column_names:
            raise ValueError("Dataset must contain 'original_text' and 'extractive_summary' columns.")
    except Exception as e:
        print(f"\nError loading raw GovReport dataset from {GENERATED_DATASET_DIR}: {e}")
        print("Please ensure the directory exists and contains 'train.json', 'validation.json', 'test.json'.")
        exit()

    tokenizer_for_preprocessing = LongformerTokenizer.from_pretrained(MODEL_NAME)

    def generate_extractive_labels(examples):
        processed_examples = {
            "input_ids": [],
            "attention_mask": [],
            "global_attention_mask": [],
            "labels": [],
        }

        for i in tqdm(range(len(examples["original_text"])), desc="Generating labels"):
            document_text = examples["original_text"][i]
            extractive_summary_reference = examples["extractive_summary"][i]

            if not document_text or not extractive_summary_reference:
                continue

            sentences = sent_tokenize(document_text)
            if not sentences:
                continue

            sentence_bert_scores = []
            for sent_idx, sentence in enumerate(sentences):
                score = bertscore_metric.compute(
                    predictions=[sentence],
                    references=[extractive_summary_reference],
                    lang="en",
                )
                sentence_bert_scores.append((score["f1"][0], sent_idx))

            sentence_bert_scores.sort(key=lambda x: x[0], reverse=True)

            BERTSCORE_THRESHOLD = 0.80
            labels_for_document = [0] * len(sentences)

            for score, sent_idx in sentence_bert_scores:
                if score >= BERTSCORE_THRESHOLD:
                    labels_for_document[sent_idx] = 1

            for sent_idx, sentence in enumerate(sentences):
                inputs = tokenizer_for_preprocessing(
                    sentence,
                    truncation=True,
                    max_length=SENTENCE_MAX_LENGTH,
                    padding="max_length",
                    return_tensors="pt"
                )

                global_attention_mask = torch.zeros_like(inputs["input_ids"])
                global_attention_mask[:, 0] = 1

                processed_examples["input_ids"].append(inputs["input_ids"].squeeze(0).tolist())
                processed_examples["attention_mask"].append(inputs["attention_mask"].squeeze(0).tolist())
                processed_examples["global_attention_mask"].append(global_attention_mask.squeeze(0).tolist())
                processed_examples["labels"].append(labels_for_document[sent_idx])

        return processed_examples

    def postprocess_text_for_rouge(preds, labels):
        preds = [pred.strip() for pred in preds]
        labels = [label.strip() for label in labels]
        preds = ["\n".join(sent_tokenize(pred)) for pred in preds]
        labels = ["\n".join(sent_tokenize(label)) for label in labels]
        return preds, labels

    print("\nGenerating extractive labels for dataset splits (this may take a while)...")
    original_column_names = govreport_data_splits["train"].column_names

    tokenized_datasets = govreport_data_splits.map(
        generate_extractive_labels,
        batched=True,
        remove_columns=original_column_names,
        num_proc=os.cpu_count() if os.cpu_count() else 1
    )
    print("\nExtractive labels generated and tokenized.")
    print(tokenized_datasets)

    print(f"\nSaving processed dataset to: {PROCESSED_DATA_DIR}")
    tokenized_datasets.save_to_disk(PROCESSED_DATA_DIR)
    print("Processed dataset saved successfully!")

tokenizer = LongformerTokenizer.from_pretrained(MODEL_NAME)

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)

    print("\n--- Metrics Debugging ---")
    print(f"Total validation samples: {len(labels)}")
    print(f"Number of true positive labels (1s) in data: {np.sum(labels == 1)}")
    print(f"Number of predicted positive labels (1s) by model: {np.sum(predictions == 1)}")
    print("--- End Debugging ---")

    precision, recall, f1, _ = precision_recall_fscore_support(
        labels, predictions, average='binary', pos_label=1, zero_division=0
    )
    accuracy = accuracy_score(labels, predictions)

    return {"accuracy": accuracy, "precision": precision, "recall": recall, "f1": f1}


model = LongformerForSequenceClassification.from_pretrained(MODEL_NAME, num_labels=2)

train_labels = tokenized_datasets["train"]["labels"]
label_counts = Counter(train_labels)
num_class_0 = label_counts.get(0, 0)
num_class_1 = label_counts.get(1, 0)
total_samples = len(train_labels)

print(f"\nLabel distribution in training set: Class 0 (Non-summary): {num_class_0}, Class 1 (Summary): {num_class_1}")

if num_class_0 > 0 and num_class_1 > 0:
    weight_for_class_0 = total_samples / (2 * num_class_0)
    weight_for_class_1 = total_samples / (2 * num_class_1)
    class_weights = torch.tensor([weight_for_class_0, weight_for_class_1], dtype=torch.float)
    print(f"Calculated class weights: Class 0: {weight_for_class_0:.4f}, Class 1: {weight_for_class_1:.4f}")
else:
    print("Warning: One or both classes are missing in the training data. Using uniform weights.")
    class_weights = torch.tensor([1.0, 1.0], dtype=torch.float)

if torch.cuda.is_available():
    class_weights = class_weights.to("cuda")
    model.to("cuda")
    print("LongformerForSequenceClassification model and class weights moved to GPU.")
else:
    print("No GPU found, model and class weights running on CPU.")

class CustomTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False, num_items_in_batch=None, **kwargs):
        labels = inputs.pop("labels")
        outputs = model(**inputs)
        logits = outputs.logits
        loss_fct = torch.nn.CrossEntropyLoss(weight=class_weights)
        loss = loss_fct(logits.view(-1, self.model.config.num_labels), labels.view(-1))
        return (loss, outputs) if return_outputs else loss

training_args = TrainingArguments(
    output_dir=OUTPUT_DIR,
    num_train_epochs=3,
    per_device_train_batch_size=2,
    per_device_eval_batch_size=2,
    gradient_accumulation_steps=4,
    gradient_checkpointing=True,
    fp16=torch.cuda.is_available(),
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir=f"{OUTPUT_DIR}/logs",
    logging_steps=100,
    eval_strategy="steps",
    save_strategy="steps",
    save_steps=50,
    eval_steps=50,
    save_total_limit=2,
    load_best_model_at_end=False,
    report_to="none",
)

trainer = CustomTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)

print("\nStarting Longformer extractive summarization training...")
last_checkpoint = None
if os.path.isdir(training_args.output_dir):
    checkpoints = [d for d in os.listdir(training_args.output_dir) if d.startswith("checkpoint-")]
    if checkpoints:
        last_checkpoint = os.path.join(training_args.output_dir, max(checkpoints, key=lambda x: int(x.split('-')[1])))
        print(f"Found existing checkpoint: {last_checkpoint}. Resuming training from here.")

try:
    # Note: If you want to use the new BERTScore-labeled data, do NOT resume from a checkpoint here.
    # Instead, let it start training from scratch on the newly generated dataset.
    trainer.train(resume_from_checkpoint=last_checkpoint)
except Exception as e:
    print(f"Error during training or resuming: {e}")
    print("If this is an 'AttributeError: 'NoneType' object has no attribute 'load_state_dict'' related to fp16,")
    print("it might mean the previous checkpoint was saved inconsistently. Consider deleting the folder and restarting.")

print("\nTraining complete! Best model saved to:", trainer.state.best_model_checkpoint)

print("\nEvaluating on test set...")
test_results = trainer.evaluate(tokenized_datasets["test"])
print("Test Results:", test_results)

# %% [markdown]
# #pip and mounting drive

# %%
# !pip install rouge_score
# !pip install evaluate
# Out:
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rouge_score) (2.0.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (4.67.1)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=5ef17922c29c8bb1f2ae15c84fda55d13e00514e2206ad97a465a6d68cd4cdc4
#   Stored in directory: /root/.cache/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2
# Collecting evaluate
#   Downloading evaluate-0.4.5-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.34.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from evaluate) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.12.14)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2025.7.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Downloading evaluate-0.4.5-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 5.6 MB/s eta 0:00:00
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.5

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/
# Out:
# 'Colab Notebooks'/                     longformer_processed_govreport/
#  govreport_tfidf_vscode2/              longformer_processed_govreport.zip
#  longformer_extractive_govreport/     'reviews media'/
#  longformer_extractive_govreport.zip

# %%
import zipfile
with zipfile.ZipFile("longformer_processed_govreport.zip", 'r') as zip_ref:
        zip_ref.extractall("")
